# %% [markdown]
# # Analysis of taxi rides in New York City
#
# In this notebook, we will analyse a dataset about the taxi rides taken in New York City. We will be analysing some trends over the course of x months and then see if the weather has any impact on the rides using a weather API.

# %% [markdown]
# # Loading packages
#
# We will need to load some of the important packages at the beginning.
# The two that we will need for sure are pandas (pd) and numpy (np).

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %% [markdown]
# ## Load the data
#
# We are loading 3 number of months that will add up to more than 1 million rows. Through filtering and merging, we will reach the 1 million rows limit. However, sincee we are looking at trends, we will create one graph to see change over time.

# %%
march = pd.read_csv('Data/yellow_tripdata_2020_03.csv', low_memory=False)
april = pd.read_csv('Data/yellow_tripdata_2020_04.csv', low_memory=False)
may = pd.read_csv('Data/yellow_tripdata_2020_05.csv', low_memory=False)

# %% [markdown]
#  We are merging all the tables together to create one table for whole spring.

# %%
spring = march.append(april).append(may)

# %%
spring.count()
# Out:
# VendorID                 3477765
# tpep_pickup_datetime     3593656
# tpep_dropoff_datetime    3593656
# passenger_count          3477765
# trip_distance            3593656
# RatecodeID               3477765
# store_and_fwd_flag       3477765
# PULocationID             3593656
# DOLocationID             3593656
# payment_type             3477765
# fare_amount              3593656
# extra                    3593656
# mta_tax                  3593656
# tip_amount               3593656
# tolls_amount             3593656
# improvement_surcharge    3593656
# total_amount             3593656
# congestion_surcharge     3593656
# dtype: int64

# %% [markdown]
# This combined dataset has too many rows but there seems to be some mismatching so we can do some cleaning and filtering.

# %% [markdown]
# ### Cleaning of full data

# %%
spring.dropna(inplace=True)

# %%
spring['tpep_pickup_datetime'] = pd.to_datetime(spring['tpep_pickup_datetime'], format='%Y-%m-%d %H:%M')
spring['tpep_dropoff_datetime'] = pd.to_datetime(spring['tpep_dropoff_datetime'], format='%Y-%m-%d %H:%M')

# %%
spring['pickup_date'] = spring['tpep_pickup_datetime'].dt.date

# %%
spring_grouped = spring.groupby('pickup_date').size().reset_index()
spring_grouped.columns=['pickup_date', 'nb_trips']

# %%
sns.lineplot(data = spring_grouped, x = 'pickup_date', y = 'nb_trips')
# Out:
# <AxesSubplot:xlabel='pickup_date', ylabel='nb_trips'>

# %%
march.count()
# Out:
# VendorID                 2969805
# tpep_pickup_datetime     3007292
# tpep_dropoff_datetime    3007292
# passenger_count          2969805
# trip_distance            3007292
# RatecodeID               2969805
# store_and_fwd_flag       2969805
# PULocationID             3007292
# DOLocationID             3007292
# payment_type             2969805
# fare_amount              3007292
# extra                    3007292
# mta_tax                  3007292
# tip_amount               3007292
# tolls_amount             3007292
# improvement_surcharge    3007292
# total_amount             3007292
# congestion_surcharge     3007292
# dtype: int64

# %%
april.count()
# Out:
# VendorID                 218480
# tpep_pickup_datetime     237993
# tpep_dropoff_datetime    237993
# passenger_count          218480
# trip_distance            237993
# RatecodeID               218480
# store_and_fwd_flag       218480
# PULocationID             237993
# DOLocationID             237993
# payment_type             218480
# fare_amount              237993
# extra                    237993
# mta_tax                  237993
# tip_amount               237993
# tolls_amount             237993
# improvement_surcharge    237993
# total_amount             237993
# congestion_surcharge     237993
# dtype: int64

# %% [markdown]
# Looks like there is a discapancy in the data in April, since there are signifcantly less observations in this month with almost the same number of days. We can see this in the graoh but also the actual counts. This is probably due to the shutdown in NYC due to COVID reaching the US. Therefore, we will not use months after March for analysis since it does not show the normal movement of people.

# %% [markdown]
# Looks like there are some columns that have NA values or somehow shorted, so we will filter those out first. After that we will filter the data by vendor ID and use just 1 so that we can include more variaty in the date (as in more time).

# %%
march.dropna(inplace=True)

# %%
march = march[march['VendorID'] == 1]

# %%
march = march.reset_index()
march = march.drop('index', axis = 1)

# %%
march.count()
# Out:
# VendorID                 988227
# tpep_pickup_datetime     988227
# tpep_dropoff_datetime    988227
# passenger_count          988227
# trip_distance            988227
# RatecodeID               988227
# store_and_fwd_flag       988227
# PULocationID             988227
# DOLocationID             988227
# payment_type             988227
# fare_amount              988227
# extra                    988227
# mta_tax                  988227
# tip_amount               988227
# tolls_amount             988227
# improvement_surcharge    988227
# total_amount             988227
# congestion_surcharge     988227
# dtype: int64

# %% [markdown]
# With these filterings we managed to bring down the cound of the observations to under 1 million, which we can use now for analysis.

# %% [markdown]
# ## Data cleaning of only March
#
# Now that we have the data that we will work with, we can look into what is needed in terms of data cleaning.

# %%
march
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            1.0  2020-03-01 00:31:13   2020-03-01 01:01:42              1.0
# 1            1.0  2020-03-01 00:52:18   2020-03-01 00:59:16              1.0
# 2            1.0  2020-03-01 00:43:19   2020-03-01 00:58:27              0.0
# 3            1.0  2020-03-01 00:04:43   2020-03-01 00:23:17              1.0
# 4            1.0  2020-03-01 00:43:21   2020-03-01 01:14:36              1.0
# ...          ...                  ...                   ...              ...
# 988222       1.0  2020-03-31 23:40:38   2020-03-31 23:55:53              1.0
# 988223       1.0  2020-03-31 23:31:30   2020-03-31 23:35:22              0.0
# 988224       1.0  2020-03-31 23:07:38   2020-03-31 23:19:20              1.0
# 988225       1.0  2020-03-31 23:38:47   2020-03-31 23:44:58              1.0
# 988226       1.0  2020-03-31 23:36:21   2020-04-01 00:09:05              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 4.7         1.0                  N            88
# 1                 1.1         1.0                  N           246
# 2                 4.4         1.0                  N            79
# 3                 3.5         1.0                  Y           113
# 4                14.1         1.0                  Y           237
# ...               ...         ...                ...           ...
# 988222            5.9         1.0                  N           127
# 988223            0.8         1.0                  Y           263
# 988224            4.3         1.0                  N           113
# 988225            1.7         1.0                  N            68
# 988226           11.9         1.0                  N           132
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                255           1.0         22.0    3.0      0.5        2.00
# 1                 90           1.0          6.0    3.0      0.5        1.95
# 2                261           1.0         16.5    3.0      0.5        4.05
# 3                142           1.0         15.0    3.0      0.5        3.75
# 4                 14           1.0         40.5    3.0      0.5        8.85
# ...              ...           ...          ...    ...      ...         ...
# 988222            43           2.0         19.5    0.5      0.5        0.00
# 988223           237           1.0          5.0    3.0      0.5        2.60
# 988224           236           1.0         14.5    3.0      0.5        2.70
# 988225           142           1.0          7.5    3.0      0.5        1.00
# 988226           188           1.0         37.5    0.5      0.5        7.75
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 0                0.0                    0.3         27.80
# 1                0.0                    0.3         11.75
# 2                0.0                    0.3         24.35
# 3                0.0                    0.3         22.55
# 4                0.0                    0.3         53.15
# ...              ...                    ...           ...
# 988222           0.0                    0.3         20.80
# 988223           0.0                    0.3         11.40
# 988224           0.0                    0.3         21.00
# 988225           0.0                    0.3         12.30
# 988226           0.0                    0.3         46.55
#
#         congestion_surcharge
# 0                        2.5
# 1                        2.5
# 2                        2.5
# 3                        2.5
# 4                        2.5
# ...                      ...
# 988222                   0.0
# 988223                   2.5
# 988224                   2.5
# 988225                   2.5
# 988226                   0.0
#
# [988227 rows x 18 columns]

# %%
march.dtypes
# Out:
# VendorID                 float64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %% [markdown]
# Looks like the one thing we need to change is the datetime columns. They should be transformed into actual datetime instead of objects.
# We can also change the store_and_fwd_flag, payment_type,pickup and dropoff locations into a categorical since they are factors.

# %%
march['tpep_pickup_datetime'] = pd.to_datetime(march['tpep_pickup_datetime'], format='%Y-%m-%d %H:%M')
march['tpep_dropoff_datetime'] = pd.to_datetime(march['tpep_dropoff_datetime'], format='%Y-%m-%d %H:%M')

# %%
march['store_and_fwd_flag'] = march.store_and_fwd_flag.astype('category')
march['payment_type'] = march.payment_type.astype('category')
march['PULocationID'] = march.PULocationID.astype('category')
march['DOLocationID'] = march.DOLocationID.astype('category')
march['RatecodeID'] = march.RatecodeID.astype('category')

# %%
march['VendorID'] = march.VendorID.astype('int')
march['passenger_count'] = march.passenger_count.astype('int')

# %%
march.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                     category
# store_and_fwd_flag             category
# PULocationID                   category
# DOLocationID                   category
# payment_type                   category
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
march
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2020-03-01 00:31:13   2020-03-01 01:01:42                1
# 1              1  2020-03-01 00:52:18   2020-03-01 00:59:16                1
# 2              1  2020-03-01 00:43:19   2020-03-01 00:58:27                0
# 3              1  2020-03-01 00:04:43   2020-03-01 00:23:17                1
# 4              1  2020-03-01 00:43:21   2020-03-01 01:14:36                1
# ...          ...                  ...                   ...              ...
# 988222         1  2020-03-31 23:40:38   2020-03-31 23:55:53                1
# 988223         1  2020-03-31 23:31:30   2020-03-31 23:35:22                0
# 988224         1  2020-03-31 23:07:38   2020-03-31 23:19:20                1
# 988225         1  2020-03-31 23:38:47   2020-03-31 23:44:58                1
# 988226         1  2020-03-31 23:36:21   2020-04-01 00:09:05                1
#
#         trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0                 4.7        1.0                  N           88          255
# 1                 1.1        1.0                  N          246           90
# 2                 4.4        1.0                  N           79          261
# 3                 3.5        1.0                  Y          113          142
# 4                14.1        1.0                  Y          237           14
# ...               ...        ...                ...          ...          ...
# 988222            5.9        1.0                  N          127           43
# 988223            0.8        1.0                  Y          263          237
# 988224            4.3        1.0                  N          113          236
# 988225            1.7        1.0                  N           68          142
# 988226           11.9        1.0                  N          132          188
#
#        payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0               1.0         22.0    3.0      0.5        2.00           0.0
# 1               1.0          6.0    3.0      0.5        1.95           0.0
# 2               1.0         16.5    3.0      0.5        4.05           0.0
# 3               1.0         15.0    3.0      0.5        3.75           0.0
# 4               1.0         40.5    3.0      0.5        8.85           0.0
# ...             ...          ...    ...      ...         ...           ...
# 988222          2.0         19.5    0.5      0.5        0.00           0.0
# 988223          1.0          5.0    3.0      0.5        2.60           0.0
# 988224          1.0         14.5    3.0      0.5        2.70           0.0
# 988225          1.0          7.5    3.0      0.5        1.00           0.0
# 988226          1.0         37.5    0.5      0.5        7.75           0.0
#
#         improvement_surcharge  total_amount  congestion_surcharge
# 0                         0.3         27.80                   2.5
# 1                         0.3         11.75                   2.5
# 2                         0.3         24.35                   2.5
# 3                         0.3         22.55                   2.5
# 4                         0.3         53.15                   2.5
# ...                       ...           ...                   ...
# 988222                    0.3         20.80                   0.0
# 988223                    0.3         11.40                   2.5
# 988224                    0.3         21.00                   2.5
# 988225                    0.3         12.30                   2.5
# 988226                    0.3         46.55                   0.0
#
# [988227 rows x 18 columns]

# %% [markdown]
# Now the data looks much more organized. Everything is in the correct format and now represents something meaningful. With this data, we can now do analysis.

# %% [markdown]
# ## Analytics
#
# ### Question 1
#
# Questions 1 will address the first point we would like to analyse. What kind of patterns can we find in the data?
# Some of the things we are considering analysing are the number of trips over the day, a week, or a month. Average distribution of the total amount over these time windows. These data split by Rate type or type of payment.

# %% [markdown]
# #### Creating columns for anaylsis
#
# To be able to analyse we first need to create some additional columns.
# We will extract the hours, days, and days of the week from the date.
# For this we will use the pickup time since that is more presentative when trying to analyse when people need taxis.

# %%
march['day'] = march['tpep_pickup_datetime'].dt.day
march['hour'] = march['tpep_pickup_datetime'].dt.hour
march['dayofweek'] = march['tpep_pickup_datetime'].dt.day_name()

# %% [markdown]
# #### Create dataframes for the different time increments
#
# Now we can create dataframes for the hour, day and the weekdays. This will show us distributions that we can later graph.

# %%
march_by_hour = march.groupby('hour').size()
march_by_day = march.groupby('day').size()
march_by_dayofweek = march.groupby('dayofweek', sort = False).size()

# %%
march_by_hour.plot()
# Out:
# <AxesSubplot:xlabel='hour'>

# %%
march_by_day.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
march_by_dayofweek.plot()
# Out:
# <AxesSubplot:xlabel='dayofweek'>

# %% [markdown]
# Looks like even March was affected by COVID already as you can see that the numbers drastically decreased around the 12th or the 13th. Maybe it would be better to include data from end of February and beginning March to be able to have fully unbiased data.
# There other graphs show that there is something worth analysing here, so they will be looked at in further detail later on.

# %%
avg_fair_by_hour = march.groupby(['hour','passenger_count']).agg({'fare_amount':'mean',
                                             'total_amount':'mean',
                                            'trip_distance' : 'mean'}).reset_index()
avg_fair_by_day = march.groupby(['day','passenger_count']).agg({'fare_amount':'mean',
                                             'total_amount':'mean',
                                            'trip_distance' : 'mean'}).reset_index()
avg_fair_by_dayofweek = march.groupby(['dayofweek','passenger_count'], sort = False).agg({'fare_amount':'mean',
                                             'total_amount':'mean',
                                            'trip_distance' : 'mean'}).reset_index()

# %%
import math

avg_fair_by_hour['passenger_count'] = avg_fair_by_hour['passenger_count'].apply(lambda x: math.floor(x))
avg_fair_by_day['passenger_count'] = avg_fair_by_day['passenger_count'].apply(lambda x: math.floor(x))
avg_fair_by_dayofweek['passenger_count'] = avg_fair_by_dayofweek['passenger_count'].apply(lambda x: math.floor(x))

# %%
passenger = 3
avg_fair_by_hour[avg_fair_by_hour['passenger_count'] == passenger]
# Out:
#      hour  passenger_count  fare_amount  total_amount  trip_distance
# 3       0                3    11.959096     17.696838       2.887668
# 10      1                3    11.266006     16.861540       2.718902
# 17      2                3    11.954795     17.397507       2.998082
# 24      3                3    13.123711     18.948479       2.843041
# 31      4                3    14.638672     20.648359       3.839453
# 38      5                3    23.721250     30.549917       5.966667
# 45      6                3    19.416667     26.065147       5.189216
# 52      7                3    13.303329     18.980864       3.050992
# 59      8                3    12.615434     18.309528       2.808801
# 68      9                3    15.111700     21.088980       3.372238
# 75     10                3    14.357834     20.077911       3.259671
# 82     11                3    13.835491     19.665384       3.089643
# 89     12                3    12.801920     18.157883       2.814015
# 96     13                3    13.879704     19.478696       3.275538
# 103    14                3    13.775015     19.287531       3.100592
# 110    15                3    13.189390     18.773271       2.801095
# 118    16                3    13.550027     19.921937       2.933601
# 125    17                3   346.335960    352.526244       2.668408
# 132    18                3    12.416889     18.535697       2.730786
# 139    19                3    11.923341     17.883720       2.568173
# 146    20                3    11.612808     17.330155       2.690992
# 153    21                3    12.061311     17.940495       2.841353
# 160    22                3    12.192778     18.137725       2.884627
# 168    23                3    12.812563     18.725950       3.170352

# %%
passenger_count = avg_fair_by_hour.passenger_count.unique()

fig, axes = plt.subplots(nrows=len(passenger_count)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,50))
fig.suptitle('Number of trips per hour by number of passangers')
i = 0
for passenger in passenger_count:
    sns.lineplot(data = avg_fair_by_hour[avg_fair_by_hour['passenger_count'] == passenger],
                 x = 'hour', y = 'fare_amount', ax=axes[i//2, i%2],)
    i += 1
plt.show()

# %%
passenger_count = avg_fair_by_day.passenger_count.unique()

fig, axes = plt.subplots(nrows=len(passenger_count)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,50))
fig.suptitle('Number of trips per day by number of passangers')
i = 0
for passenger in passenger_count:
    sns.lineplot(data = avg_fair_by_day[avg_fair_by_day['passenger_count'] == passenger],
                 x = 'day', y = 'fare_amount', ax=axes[i//2, i%2],)
    i += 1
plt.show()

# %%
passenger_count = avg_fair_by_dayofweek.passenger_count.unique()

fig, axes = plt.subplots(nrows=len(passenger_count)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,50))
fig.suptitle('Number of trips per day of week by number of passangers')
i = 0
for passenger in passenger_count:
    sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
                 x = 'dayofweek', y = 'fare_amount', ax=axes[i//2, i%2],)
    i += 1
plt.show()
# Out:
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],
# <ipython-input-65-14499d8440d3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data = avg_fair_by_dayofweek[avg_fair_by_day['passenger_count'] == passenger],

# %% [markdown]
# #### Looking at different aspects

# %%
fare_type_vs_payment_type = march.groupby(['RatecodeID', 'payment_type']).size().reset_index()
fare_type_vs_payment_type.columns=['RatecodeID','payment_type','nb_trips']
fare_type_vs_payment_type_pivot = fare_type_vs_payment_type.pivot(index='RatecodeID', columns='payment_type', values='nb_trips')
fare_type_vs_payment_type_pivot
# Out:
# payment_type     1.0     2.0    3.0   4.0
# RatecodeID
# 1.0           720060  228324  12419  3993
# 2.0            12831    3357    361   166
# 3.0             1387     369    130    55
# 4.0              376     231     55    24
# 5.0             2808     666    402   182
# 6.0                1       8      1     2
# 99.0              12       2      5     0

# %%
payment_type = [1.0, 2.0, 3.0, 4.0]

fig, axes = plt.subplots(nrows=len(payment_type)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,20))
fig.suptitle('Number of trips per day of week by number of passangers')
i = 0
for payment in payment_type:
    sns.scatterplot(data = fare_type_vs_payment_type[fare_type_vs_payment_type['payment_type'] == payment],
                 x = 'RatecodeID', y = 'nb_trips', ax=axes[i//2, i%2],)
    i += 1
plt.show()

# %%
fare_type_vs_pass_count = march.groupby(['RatecodeID', 'passenger_count']).size().reset_index()
fare_type_vs_pass_count.columns=['RatecodeID','passenger_count','nb_trips']
fare_type_vs_pass_count_pivot = fare_type_vs_pass_count.pivot(index= 'RatecodeID', columns='passenger_count', values='nb_trips')
fare_type_vs_pass_count_pivot
# Out:
# passenger_count      0       1       2      3      4    5    6  8  9
# RatecodeID
# 1.0              61532  744073  121015  25466  11288  769  648  1  4
# 2.0               1108   10717    3863    641    339   23   24  0  0
# 3.0                146    1295     391     71     35    2    1  0  0
# 4.0                 28     513     104     27     12    1    1  0  0
# 5.0                325    2824     653    151     76   24    5  0  0
# 6.0                  3       8       1      0      0    0    0  0  0
# 99.0                16       2       1      0      0    0    0  0  0

# %%
passenger_count = fare_type_vs_pass_count.passenger_count.unique()

fig, axes = plt.subplots(nrows=len(passenger_count)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,20))
fig.suptitle('Number of trips per day of week by number of passangers')
i = 0
for passenger in passenger_count:
    sns.scatterplot(data = fare_type_vs_pass_count[fare_type_vs_pass_count['passenger_count'] == passenger],
                 x = 'RatecodeID', y = 'nb_trips', ax=axes[i//2, i%2],)
    i += 1
plt.show()

# %%
payment_type_vs_pass_count = march.groupby(['payment_type', 'passenger_count']).size().reset_index()
payment_type_vs_pass_count.columns=['payment_type','passenger_count','nb_trips']
payment_type_vs_pass_count_pivot = payment_type_vs_pass_count.pivot(index='payment_type', columns='passenger_count', values='nb_trips')
payment_type_vs_pass_count_pivot
# Out:
# passenger_count      0       1      2      3     4    5    6  8  9
# payment_type
# 1.0              46659  574122  90151  18360  7114  596  468  1  4
# 2.0              14961  171881  33839   7496  4403  204  173  0  0
# 3.0               1201   10154   1475    355   164   10   14  0  0
# 4.0                337    3275    563    145    69    9   24  0  0

# %%
passenger_count = payment_type_vs_pass_count.passenger_count.unique()

fig, axes = plt.subplots(nrows=len(passenger_count)//2+1, ncols=2, sharex = True, sharey = True,
                         figsize=(20,20))
fig.suptitle('Number of trips per day of week by number of passangers')
i = 0
for passenger in passenger_count:
    sns.scatterplot(data = payment_type_vs_pass_count[payment_type_vs_pass_count['passenger_count'] == passenger],
                 x = 'payment_type', y = 'nb_trips', ax=axes[i//2, i%2],)
    i += 1
plt.show()

# %% [markdown]
# ## API

# %%
import requests

# %% [markdown]
# Set the params for the API

# %%
city = "New York"
from_date = "2020-3-1"
to_date = "2020-5-31"

# %%
resp = requests.get("https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{}%20{}/{}/{}?unitGroup=metric&key=BA2ZMU7Z5G69FTJEAEVC328WT&include=obs%2Cstats%2Calerts".format(city.split(' ')[0], 
                                                                                            city.split(' ')[1], from_date, to_date))
type(resp)
# Out:
# requests.models.Response

# %%
resp.text
# Out:
# '{"queryCost":92,"latitude":40.7146,"longitude":-74.0071,"resolvedAddress":"New York, NY, United States","address":"New York","timezone":"America/New_York","tzoffset":-5.0,"days":[{"datetime":"2020-03-01","datetimeEpoch":1583038800,"tempmax":8.7,"tempmin":-2.9,"temp":2.4,"feelslikemax":8.0,"feelslikemin":-7.4,"feelslike":-0.4,"dew":-8.4,"humidity":46.32,"precip":0.0,"precipprob":null,"precipcover":0.0,"preciptype":null,"snow":0.0,"snowdepth":0.0,"windgust":64.8,"windspeed":22.0,"winddir":280.6,"pressure":1020.4,"cloudcover":4.6,"visibility":16.0,"solarradiation":null,"solarenergy":null,"sunrise":"06:29:07","sunriseEpoch":1583062147,"sunset":"17:47:57","sunsetEpoch":1583102877,"moonphase":0.18,"conditions":"Clear","icon":"clear-day","stations":["72505394728","72055399999","KLGA","KJRB","KNYC","72503014732"],"source":"obs","normal":{"tempmax":[-1.1,7.4,19.6],"tempmin":[-8.3,1.3,11.8],"feelslike":[-14.1,7.4,19.6],"precip":[0.0,2.9,12.1],"humidity":[25.7,58.1,90.7],"snowdepth":[11.3,11.3,11.3],"windspeed":[0.7,19.8,33.5],"windgust":[31.7,56.9,70.9],"winddir":[45.6,199.6,308.8],"cloudcover":[0.0,35.7,99.1]},"hours":null},{"datetime":"2020-03-02","datetimeEpoch":1583125200,"tempmax":14.3,"tempmin":3.9,"temp":9.1,"feelslikemax":14.3,"feelslikemin":1.8,"feelslike":8.4,"dew":0.0,"humidity":53.31,"precip":0.24,"precipprob":null,"precipcover":4.17,"preciptype":null,"snow":0.0,"snowdepth":0.0,"windgust":61.3,"windspeed":23.4,"winddir":239.9,"pressure":1014.9,"cloudcover":14.5,"visibility":16.0,"solarradiation":null,"solarenergy":null,"sunrise":"06:27:35","sunriseEpoch":1583148455,"sunset":"17:49:05","sunsetEpoch":1583189345,"moonphase":0.23,"conditions":"Rain","icon":"rain","stations":["72505394728","72055399999","KLGA","KJRB","KNYC","72503014732"],"source":"obs","normal":{"tempmax":[-2.8,7.5,19.4],"tempmin":[-8.8,0.1,6.2],"feelslike":[-17.1,7.5,19.4],"precip":[0.0,8.7,62.8],"humidity":[37.6,62.7,89.9],"snowdepth":[14.5,14.5,14.5],"windspeed":[0.7,23.0,38.9],"windgust":[37.1,51.8,65.9],"winddir":[104.0,231.0,304.7],"cloudcover":[0.0,47.0,100.0]},"hours":null},{"datetime":"2020-03-03","datetimeEpoch":1583211600,"tempmax":14.8,"tempmin":8.9,"temp":11.1,"feelslikemax":14.8,"feelslikemin":7.8,"feelslike":10.8,"dew":7.1,"humidity":77.41,"precip":7.93,"precipprob":null,"precipcover":33.33,"preciptype":null,"snow":0.0,"snowdepth":0.0,"windgust":85.0,"windspeed":14.7,"winddir":213.8,"pressure":1004.4,"cloudcover":23.4,"visibility":14.3,"solarradiation":null,"solarenergy":null,"sunrise":"06:26:01","sunriseEpoch":1583234761,"sunset":"17:50:13","sunsetEpoch":1583275813,"moonphase":0.28,"conditions":"Rain","icon":"rain","stations":["72505394728","72055399999","KLGA","KJRB","KNYC","72503014732"],"source":"obs","normal":{"tempmax":[-3.1,6.4,16.2],"tempmin":[-11.1,-0.9,8.4],"feelslike":[-21.2,6.4,16.2],"precip":[0.0,2.9,24.9],"humidity":[32.4,54.3,78.2],"snowdepth":[12.3,12.3,12.3],"windspeed":[1.1,22.3,44.6],"windgust":[31.7,48.6,68.4],"winddir":[115.5,226.1,314.7],"cloudcover":[0.0,26.9,100.0]},"hours":null},{"datetime":"2020-03-04","datetimeEpoch":1583298000,"tempmax":13.8,"tempmin":7.2,"temp":10.2,"feelslikemax":13.8,"feelslikemin":3.2,"feelslike":8.9,"dew":-0.2,"humidity":50.65,"precip":0.97,"precipprob":null,"precipcover":12.5,"preciptype":null,"snow":0.0,"snowdepth":0.0,"windgust":79.8,"windspeed":39.6,"winddir":270.9,"pressure":1007.2,"cloudcover":7.1,"visibility":16.0,"solarradiation":null,"solarenergy":null,"sunrise":"06:24:28","sunriseEpoch":1583321068,"sunset":"17:51:20","sunsetEpoch":1583362280,"moonphase":0.34,"conditions":"Rain","icon":"rain","stations":["72505394728","72055399999","KLGA","KJRB","KNYC","72503014732"],"source":"obs","normal":{"tempmax":[-2.1,5.5,17.2],"tempmin":[-10.3,-1.5,7.2],"feelslike":[-14.4,5.5,17.2],"precip":[0.0,1.7,9.5],"humidity":[40.9,57.8,89.9],"snowdepth":[12.5,12.5,12.5],"windspeed":[0.7,19.8,37.1],"windgust":[35.3,54.7,75.6],"winddir":[71.0,218.8,309.6],"cloudcover":[0.0,41.5,100.0]},"hours":null},{"datetime ...

# %% [markdown]
# Parsing the response string

# %%
import json

# %%
weather = json.loads(resp.text)
weather
# Out:
# {'queryCost': 92,
#  'latitude': 40.7146,
#  'longitude': -74.0071,
#  'resolvedAddress': 'New York, NY, United States',
#  'address': 'New York',
#  'timezone': 'America/New_York',
#  'tzoffset': -5.0,
#  'days': [{'datetime': '2020-03-01',
#    'datetimeEpoch': 1583038800,
#    'tempmax': 8.7,
#    'tempmin': -2.9,
#    'temp': 2.4,
#    'feelslikemax': 8.0,
#    'feelslikemin': -7.4,
#    'feelslike': -0.4,
#    'dew': -8.4,
#    'humidity': 46.32,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 22.0,
#    'winddir': 280.6,
#    'pressure': 1020.4,
#    'cloudcover': 4.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:29:07',
#    'sunriseEpoch': 1583062147,
#    'sunset': '17:47:57',
#    'sunsetEpoch': 1583102877,
#    'moonphase': 0.18,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-1.1, 7.4, 19.6],
#     'tempmin': [-8.3, 1.3, 11.8],
#     'feelslike': [-14.1, 7.4, 19.6],
#     'precip': [0.0, 2.9, 12.1],
#     'humidity': [25.7, 58.1, 90.7],
#     'snowdepth': [11.3, 11.3, 11.3],
#     'windspeed': [0.7, 19.8, 33.5],
#     'windgust': [31.7, 56.9, 70.9],
#     'winddir': [45.6, 199.6, 308.8],
#     'cloudcover': [0.0, 35.7, 99.1]},
#    'hours': None},
#   {'datetime': '2020-03-02',
#    'datetimeEpoch': 1583125200,
#    'tempmax': 14.3,
#    'tempmin': 3.9,
#    'temp': 9.1,
#    'feelslikemax': 14.3,
#    'feelslikemin': 1.8,
#    'feelslike': 8.4,
#    'dew': 0.0,
#    'humidity': 53.31,
#    'precip': 0.24,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.3,
#    'windspeed': 23.4,
#    'winddir': 239.9,
#    'pressure': 1014.9,
#    'cloudcover': 14.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:27:35',
#    'sunriseEpoch': 1583148455,
#    'sunset': '17:49:05',
#    'sunsetEpoch': 1583189345,
#    'moonphase': 0.23,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-2.8, 7.5, 19.4],
#     'tempmin': [-8.8, 0.1, 6.2],
#     'feelslike': [-17.1, 7.5, 19.4],
#     'precip': [0.0, 8.7, 62.8],
#     'humidity': [37.6, 62.7, 89.9],
#     'snowdepth': [14.5, 14.5, 14.5],
#     'windspeed': [0.7, 23.0, 38.9],
#     'windgust': [37.1, 51.8, 65.9],
#     'winddir': [104.0, 231.0, 304.7],
#     'cloudcover': [0.0, 47.0, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-03',
#    'datetimeEpoch': 1583211600,
#    'tempmax': 14.8,
#    'tempmin': 8.9,
#    'temp': 11.1,
#    'feelslikemax': 14.8,
#    'feelslikemin': 7.8,
#    'feelslike': 10.8,
#    'dew': 7.1,
#    'humidity': 77.41,
#    'precip': 7.93,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 85.0,
#    'windspeed': 14.7,
#    'winddir': 213.8,
#    'pressure': 1004.4,
#    'cloudcover': 23.4,
#    'visibility': 14.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:26:01',
#    'sunriseEpoch': 1583234761,
#    'sunset': '17:50:13',
#    'sunsetEpoch': 1583275813,
#    'moonphase': 0.28,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-3.1, 6.4, 16.2],
#     'tempmin': [-11.1, -0.9, 8.4],
#     'feelslike': [-21.2, 6.4, 16.2],
#     'precip': [0.0, 2.9, 24.9],
#     'humidity': [32.4, 54.3, 78.2],
#     'snowdepth': [12.3, 12.3, 12.3],
#     'windspeed': [1.1, 22.3, 44.6],
#     'windgust': [31.7, 48.6, 68.4],
#     'winddir': [115.5, 226.1, 314.7],
#     'cloudcover': [0.0, 26.9, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-04',
#    'datetimeEpoch': 1583298000,
#    'tempmax': 13.8,
#    'tempmin': 7.2,
#    'temp': 10.2,
#    'feelslikemax': 13.8,
#    'feelslikemin': 3.2,
#    'feelslike': 8.9,
#    'dew': -0.2,
#    'humidity': 50.65,
#    'precip': 0.97,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 79.8,
#    'windspeed': 39.6,
#    'winddir': 270.9,
#    'pressure': 1007.2,
#    'cloudcover': 7.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:24:28',
#    'sunriseEpoch': 1583321068,
#    'sunset': '17:51:20',
#    'sunsetEpoch': 1583362280,
#    'moonphase': 0.34,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-2.1, 5.5, 17.2],
#     'tempmin': [-10.3, -1.5, 7.2],
#     'feelslike': [-14.4, 5.5, 17.2],
#     'precip': [0.0, 1.7, 9.5],
#     'humidity': [40.9, 57.8, 89.9],
#     'snowdepth': [12.5, 12.5, 12.5],
#     'windspeed': [0.7, 19.8, 37.1],
#     'windgust': [35.3, 54.7, 75.6],
#     'winddir': [71.0, 218.8, 309.6],
#     'cloudcover': [0.0, 41.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-05',
#    'datetimeEpoch': 1583384400,
#    'tempmax': 12.1,
#    'tempmin': 4.3,
#    'temp': 7.6,
#    'feelslikemax': 12.1,
#    'feelslikemin': 2.3,
#    'feelslike': 6.5,
#    'dew': -2.1,
#    'humidity': 51.97,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 73.8,
#    'windspeed': 14.1,
#    'winddir': 254.4,
#    'pressure': 1018.8,
#    'cloudcover': 1.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:22:53',
#    'sunriseEpoch': 1583407373,
#    'sunset': '17:52:27',
#    'sunsetEpoch': 1583448747,
#    'moonphase': 0.38,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [0.1, 6.3, 15.1],
#     'tempmin': [-8.6, -1.5, 6.7],
#     'feelslike': [-14.2, 6.3, 15.1],
#     'precip': [0.0, 2.3, 16.8],
#     'humidity': [31.6, 55.6, 99.8],
#     'snowdepth': [17.9, 17.9, 17.9],
#     'windspeed': [0.7, 20.9, 37.1],
#     'windgust': [35.3, 52.9, 68.4],
#     'winddir': [92.3, 212.7, 298.6],
#     'cloudcover': [0.0, 36.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-06',
#    'datetimeEpoch': 1583470800,
#    'tempmax': 7.8,
#    'tempmin': 3.8,
#    'temp': 5.5,
#    'feelslikemax': 5.2,
#    'feelslikemin': -0.5,
#    'feelslike': 2.9,
#    'dew': 2.2,
#    'humidity': 79.77,
#    'precip': 4.17,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 25.6,
#    'winddir': 82.2,
#    'pressure': 1012.8,
#    'cloudcover': 28.2,
#    'visibility': 14.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:21:18',
#    'sunriseEpoch': 1583493678,
#    'sunset': '17:53:34',
#    'sunsetEpoch': 1583535214,
#    'moonphase': 0.43,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-6.0, 6.5, 16.7],
#     'tempmin': [-11.0, -1.0, 10.1],
#     'feelslike': [-20.7, 6.5, 16.7],
#     'precip': [0.0, 4.0, 51.3],
#     'humidity': [26.1, 56.4, 97.6],
#     'snowdepth': [20.8, 20.8, 20.8],
#     'windspeed': [0.7, 19.8, 38.9],
#     'windgust': [29.5, 59.8, 74.2],
#     'winddir': [64.5, 181.9, 298.3],
#     'cloudcover': [0.0, 28.8, 97.1]},
#    'hours': None},
#   {'datetime': '2020-03-07',
#    'datetimeEpoch': 1583557200,
#    'tempmax': 11.0,
#    'tempmin': 3.3,
#    'temp': 5.9,
#    'feelslikemax': 11.0,
#    'feelslikemin': 1.1,
#    'feelslike': 4.4,
#    'dew': -5.8,
#    'humidity': 49.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.3,
#    'windspeed': 13.0,
#    'winddir': 304.5,
#    'pressure': 1021.9,
#    'cloudcover': 16.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:19:43',
#    'sunriseEpoch': 1583579983,
#    'sunset': '17:54:41',
#    'sunsetEpoch': 1583621681,
#    'moonphase': 0.46,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-5.8, 8.6, 21.2],
#     'tempmin': [-11.0, 0.2, 10.9],
#     'feelslike': [-16.2, 8.6, 21.2],
#     'precip': [0.0, 3.9, 30.8],
#     'humidity': [35.3, 59.9, 92.6],
#     'snowdepth': [15.3, 15.3, 15.3],
#     'windspeed': [0.7, 19.8, 31.7],
#     'windgust': [38.9, 51.8, 59.4],
#     'winddir': [61.0, 182.6, 277.9],
#     'cloudcover': [0.0, 24.6, 69.2]},
#    'hours': None},
#   {'datetime': '2020-03-08',
#    'datetimeEpoch': 1583643600,
#    'tempmax': 15.0,
#    'tempmin': 2.2,
#    'temp': 8.1,
#    'feelslikemax': 0.0,
#    'feelslikemin': 0.0,
#    'feelslike': None,
#    'dew': -5.8,
#    'humidity': 37.85,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 93.2,
#    'windspeed': 18.2,
#    'winddir': 261.9,
#    'pressure': 1029.9,
#    'cloudcover': 9.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:07',
#    'sunriseEpoch': 1583666287,
#    'sunset': '18:55:47',
#    'sunsetEpoch': 1583708147,
#    'moonphase': 0.49,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [1.2, 9.9, 21.2],
#     'tempmin': [-8.3, 1.5, 11.9],
#     'feelslike': [-16.1, 9.9, 21.2],
#     'precip': [0.0, 2.7, 19.1],
#     'humidity': [34.9, 60.3, 93.2],
#     'snowdepth': [11.5, 11.5, 11.5],
#     'windspeed': [0.7, 20.9, 35.3],
#     'windgust': [42.5, 67.7, 81.4],
#     'winddir': [75.7, 214.2, 311.7],
#     'cloudcover': [0.0, 33.0, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-09',
#    'datetimeEpoch': 1583726400,
#    'tzoffset': -4.0,
#    'tempmax': 21.7,
#    'tempmin': 6.8,
#    'temp': 13.6,
#    'feelslikemax': 15.0,
#    'feelslikemin': -0.5,
#    'feelslike': 6.8,
#    'dew': -2.1,
#    'humidity': 35.43,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 84.0,
#    'windspeed': 22.1,
#    'winddir': 262.7,
#    'pressure': 1026.8,
#    'cloudcover': 0.7,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:30',
#    'sunriseEpoch': 1583752590,
#    'sunset': '18:56:53',
#    'sunsetEpoch': 1583794613,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-1.0, 9.6, 24.4],
#     'tempmin': [-10.7, 1.2, 9.3],
#     'feelslike': [-17.4, 9.6, 24.4],
#     'precip': [0.0, 0.8, 9.4],
#     'humidity': [28.4, 54.4, 85.8],
#     'snowdepth': [7.4, 7.4, 7.4],
#     'windspeed': [0.7, 20.5, 33.5],
#     'windgust': [30.6, 54.7, 77.8],
#     'winddir': [52.0, 199.1, 303.6],
#     'cloudcover': [0.0, 33.0, 99.6]},
#    'hours': None},
#   {'datetime': '2020-03-10',
#    'datetimeEpoch': 1583812800,
#    'tzoffset': -4.0,
#    'tempmax': 17.3,
#    'tempmin': 11.2,
#    'temp': 14.6,
#    'feelslikemax': 21.7,
#    'feelslikemin': 4.6,
#    'feelslike': 12.8,
#    'dew': 5.8,
#    'humidity': 56.04,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 83.5,
#    'windspeed': 28.8,
#    'winddir': 267.0,
#    'pressure': 1018.1,
#    'cloudcover': 22.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:53',
#    'sunriseEpoch': 1583838893,
#    'sunset': '18:57:59',
#    'sunsetEpoch': 1583881079,
#    'moonphase': 0.51,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-2.1, 9.2, 25.7],
#     'tempmin': [-7.1, 1.5, 17.9],
#     'feelslike': [-12.9, 9.2, 25.7],
#     'precip': [0.0, 2.6, 27.1],
#     'humidity': [34.7, 56.3, 90.8],
#     'snowdepth': [4.0, 4.0, 4.0],
#     'windspeed': [0.4, 19.8, 33.5],
#     'windgust': [25.9, 54.0, 76.0],
#     'winddir': [52.5, 189.4, 311.4],
#     'cloudcover': [0.0, 31.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-11',
#    'datetimeEpoch': 1583899200,
#    'tzoffset': -4.0,
#    'tempmax': 14.3,
#    'tempmin': 7.1,
#    'temp': 10.4,
#    'feelslikemax': 17.3,
#    'feelslikemin': 11.2,
#    'feelslike': 14.6,
#    'dew': -0.1,
#    'humidity': 49.34,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 76.0,
#    'windspeed': 12.4,
#    'winddir': 184.2,
#    'pressure': 1018.9,
#    'cloudcover': 14.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:16',
#    'sunriseEpoch': 1583925196,
#    'sunset': '18:59:05',
#    'sunsetEpoch': 1583967545,
#    'moonphase': 0.53,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [0.3, 10.5, 19.4],
#     'tempmin': [-7.1, 2.3, 8.9],
#     'feelslike': [-14.6, 10.5, 19.4],
#     'precip': [0.0, 1.7, 27.5],
#     'humidity': [31.9, 56.9, 85.8],
#     'snowdepth': [3.0, 3.0, 3.0],
#     'windspeed': [0.7, 19.8, 31.7],
#     'windgust': [35.3, 54.0, 78.1],
#     'winddir': [62.3, 223.7, 320.9],
#     'cloudcover': [0.0, 34.1, 99.6]},
#    'hours': None},
#   {'datetime': '2020-03-12',
#    'datetimeEpoch': 1583985600,
#    'tzoffset': -4.0,
#    'tempmax': 8.9,
#    'tempmin': 6.7,
#    'temp': 8.2,
#    'feelslikemax': 14.3,
#    'feelslikemin': 5.7,
#    'feelslike': 10.0,
#    'dew': 2.8,
#    'humidity': 69.87,
#    'precip': 0.04,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 23.5,
#    'winddir': 67.8,
#    'pressure': 1020.6,
#    'cloudcover': 35.6,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:39',
#    'sunriseEpoch': 1584011499,
#    'sunset': '19:00:10',
#    'sunsetEpoch': 1584054010,
#    'moonphase': 0.56,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [0.9, 9.6, 21.2],
#     'tempmin': [-5.8, 2.4, 10.1],
#     'feelslike': [-11.8, 9.6, 21.2],
#     'precip': [0.0, 2.4, 20.2],
#     'humidity': [24.7, 57.0, 86.6],
#     'snowdepth': [11.5, 11.5, 11.5],
#     'windspeed': [1.1, 20.5, 38.9],
#     'windgust': [47.9, 50.8, 59.4],
#     'winddir': [42.0, 213.8, 310.0],
#     'cloudcover': [0.0, 30.3, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-13',
#    'datetimeEpoch': 1584072000,
#    'tzoffset': -4.0,
#    'tempmax': 20.7,
#    'tempmin': 8.2,
#    'temp': 13.0,
#    'feelslikemax': 8.4,
#    'feelslikemin': 5.0,
#    'feelslike': 6.4,
#    'dew': 5.4,
#    'humidity': 68.06,
#    'precip': 1.12,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.7,
#    'windspeed': 32.9,
#    'winddir': 196.6,
#    'pressure': 1012.4,
#    'cloudcover': 45.3,
#    'visibility': 13.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:01',
#    'sunriseEpoch': 1584097801,
#    'sunset': '19:01:15',
#    'sunsetEpoch': 1584140475,
#    'moonphase': 0.6,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [1.8, 8.9, 23.1],
#     'tempmin': [-7.6, 2.2, 12.1],
#     'feelslike': [-10.0, 8.9, 23.1],
#     'precip': [0.0, 7.6, 98.1],
#     'humidity': [33.6, 60.1, 98.7],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.4, 20.2, 48.2],
#     'windgust': [33.5, 61.2, 73.8],
#     'winddir': [57.5, 183.6, 307.8],
#     'cloudcover': [0.0, 35.8, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-14',
#    'datetimeEpoch': 1584158400,
#    'tzoffset': -4.0,
#    'tempmax': 14.9,
#    'tempmin': 6.7,
#    'temp': 10.0,
#    'feelslikemax': 20.7,
#    'feelslikemin': 5.0,
#    'feelslike': 12.3,
#    'dew': -4.5,
#    'humidity': 36.1,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.1,
#    'windspeed': 15.2,
#    'winddir': 305.5,
#    'pressure': 1025.8,
#    'cloudcover': 12.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:22',
#    'sunriseEpoch': 1584184102,
#    'sunset': '19:02:20',
#    'sunsetEpoch': 1584226940,
#    'moonphase': 0.65,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [1.0, 9.6, 21.1],
#     'tempmin': [-5.9, 2.4, 14.3],
#     'feelslike': [-13.1, 9.6, 21.1],
#     'precip': [0.0, 3.6, 20.5],
#     'humidity': [32.4, 59.7, 89.3],
#     'snowdepth': [173.0, 173.0, 173.0],
#     'windspeed': [0.7, 22.3, 46.4],
#     'windgust': [31.7, 58.7, 76.0],
#     'winddir': [42.3, 183.8, 302.3],
#     'cloudcover': [0.0, 33.7, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-15',
#    'datetimeEpoch': 1584244800,
#    'tzoffset': -4.0,
#    'tempmax': 13.7,
#    'tempmin': 6.6,
#    'temp': 9.0,
#    'feelslikemax': 14.9,
#    'feelslikemin': 3.8,
#    'feelslike': 9.4,
#    'dew': -4.1,
#    'humidity': 40.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 20.4,
#    'winddir': 131.5,
#    'pressure': 1030.7,
#    'cloudcover': 22.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:44',
#    'sunriseEpoch': 1584270404,
#    'sunset': '19:03:25',
#    'sunsetEpoch': 1584313405,
#    'moonphase': 0.71,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-1.4, 10.4, 19.8],
#     'tempmin': [-5.7, 3.4, 9.4],
#     'feelslike': [-12.5, 10.4, 19.8],
#     'precip': [0.0, 2.0, 13.4],
#     'humidity': [37.6, 61.7, 81.7],
#     'snowdepth': [20.0, 20.0, 20.0],
#     'windspeed': [1.1, 22.0, 37.1],
#     'windgust': [51.8, 60.8, 82.4],
#     'winddir': [40.4, 195.9, 297.5],
#     'cloudcover': [0.0, 48.1, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-16',
#    'datetimeEpoch': 1584331200,
#    'tzoffset': -4.0,
#    'tempmax': 7.8,
#    'tempmin': 1.7,
#    'temp': 5.1,
#    'feelslikemax': 13.7,
#    'feelslikemin': 3.8,
#    'feelslike': 7.8,
#    'dew': -4.2,
#    'humidity': 52.04,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.6,
#    'windspeed': 29.0,
#    'winddir': 69.4,
#    'pressure': 1034.4,
#    'cloudcover': 25.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:05',
#    'sunriseEpoch': 1584356705,
#    'sunset': '19:04:29',
#    'sunsetEpoch': 1584399869,
#    'moonphase': 0.76,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [2.2, 10.1, 19.4],
#     'tempmin': [-3.9, 2.3, 9.4],
#     'feelslike': [-10.6, 10.1, 19.4],
#     'precip': [0.0, 4.5, 49.9],
#     'humidity': [32.4, 59.3, 89.7],
#     'snowdepth': [3.0, 11.5, 20.0],
#     'windspeed': [1.1, 20.9, 38.9],
#     'windgust': [30.2, 64.4, 86.0],
#     'winddir': [44.3, 180.1, 292.2],
#     'cloudcover': [0.0, 37.2, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-17',
#    'datetimeEpoch': 1584417600,
#    'tzoffset': -4.0,
#    'tempmax': 11.7,
#    'tempmin': 6.1,
#    'temp': 8.5,
#    'feelslikemax': 5.7,
#    'feelslikemin': -4.2,
#    'feelslike': 1.6,
#    'dew': 4.7,
#    'humidity': 78.0,
#    'precip': 1.71,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 21.6,
#    'winddir': 192.1,
#    'pressure': 1022.9,
#    'cloudcover': 40.8,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:26',
#    'sunriseEpoch': 1584443006,
#    'sunset': '19:05:34',
#    'sunsetEpoch': 1584486334,
#    'moonphase': 0.81,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [-0.9, 10.1, 20.7],
#     'tempmin': [-3.9, 1.7, 9.4],
#     'feelslike': [-9.8, 10.1, 20.7],
#     'precip': [0.0, 0.7, 5.4],
#     'humidity': [31.5, 53.7, 91.2],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.1, 18.4, 33.8],
#     'windgust': [38.9, 58.7, 90.7],
#     'winddir': [45.9, 195.1, 304.5],
#     'cloudcover': [0.0, 30.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-18',
#    'datetimeEpoch': 1584504000,
#    'tzoffset': -4.0,
#    'tempmax': 12.1,
#    'tempmin': 6.1,
#    'temp': 8.8,
#    'feelslikemax': 11.7,
#    'feelslikemin': 3.5,
#    'feelslike': 7.4,
#    'dew': -1.2,
#    'humidity': 50.06,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 14.4,
#    'winddir': 210.3,
#    'pressure': 1030.7,
#    'cloudcover': 9.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:47',
#    'sunriseEpoch': 1584529307,
#    'sunset': '19:06:38',
#    'sunsetEpoch': 1584572798,
#    'moonphase': 0.86,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [2.1, 10.0, 24.2],
#     'tempmin': [-2.8, 3.0, 12.2],
#     'feelslike': [-8.1, 10.0, 24.2],
#     'precip': [0.0, 1.4, 15.5],
#     'humidity': [29.0, 52.0, 93.9],
#     'snowdepth': [13.0, 13.0, 13.0],
#     'windspeed': [1.1, 20.9, 38.9],
#     'windgust': [40.7, 55.8, 64.8],
#     'winddir': [36.3, 197.1, 297.8],
#     'cloudcover': [0.0, 24.3, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-19',
#    'datetimeEpoch': 1584590400,
#    'tzoffset': -4.0,
#    'tempmax': 10.7,
#    'tempmin': 6.1,
#    'temp': 8.4,
#    'feelslikemax': 12.1,
#    'feelslikemin': 3.9,
#    'feelslike': 7.8,
#    'dew': 5.7,
#    'humidity': 83.7,
#    'precip': 22.16,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 27.1,
#    'winddir': 75.5,
#    'pressure': 1024.5,
#    'cloudcover': 50.1,
#    'visibility': 13.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:08',
#    'sunriseEpoch': 1584615608,
#    'sunset': '19:07:42',
#    'sunsetEpoch': 1584659262,
#    'moonphase': 0.9,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.1, 10.0, 23.0],
#     'tempmin': [-1.7, 2.8, 13.0],
#     'feelslike': [-6.7, 10.0, 23.0],
#     'precip': [0.0, 3.1, 24.3],
#     'humidity': [29.6, 55.8, 89.4],
#     'snowdepth': [5.0, 5.0, 5.0],
#     'windspeed': [0.7, 19.4, 35.3],
#     'windgust': [37.1, 56.2, 79.6],
#     'winddir': [83.6, 177.2, 313.5],
#     'cloudcover': [0.0, 29.0, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-20',
#    'datetimeEpoch': 1584676800,
#    'tzoffset': -4.0,
#    'tempmax': 22.9,
#    'tempmin': 8.4,
#    'temp': 14.1,
#    'feelslikemax': 10.7,
#    'feelslikemin': 2.5,
#    'feelslike': 6.3,
#    'dew': 9.4,
#    'humidity': 76.34,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.7,
#    'windspeed': 23.6,
#    'winddir': 207.9,
#    'pressure': 1014.4,
#    'cloudcover': 45.7,
#    'visibility': 12.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:29',
#    'sunriseEpoch': 1584701909,
#    'sunset': '19:08:46',
#    'sunsetEpoch': 1584745726,
#    'moonphase': 0.94,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [2.9, 9.7, 23.3],
#     'tempmin': [-2.8, 2.6, 13.3],
#     'feelslike': [-7.0, 9.7, 23.3],
#     'precip': [0.0, 3.6, 25.8],
#     'humidity': [34.2, 56.7, 87.8],
#     'snowdepth': [3.0, 5.2, 7.4],
#     'windspeed': [1.1, 18.7, 31.7],
#     'windgust': [33.5, 54.4, 74.5],
#     'winddir': [45.1, 175.5, 290.0],
#     'cloudcover': [0.0, 41.1, 99.6]},
#    'hours': None},
#   {'datetime': '2020-03-21',
#    'datetimeEpoch': 1584763200,
#    'tzoffset': -4.0,
#    'tempmax': 18.4,
#    'tempmin': 6.6,
#    'temp': 10.1,
#    'feelslikemax': 22.9,
#    'feelslikemin': 6.5,
#    'feelslike': 13.7,
#    'dew': -2.5,
#    'humidity': 42.81,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.5,
#    'windspeed': 23.4,
#    'winddir': 162.3,
#    'pressure': 1024.8,
#    'cloudcover': 19.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:49',
#    'sunriseEpoch': 1584788209,
#    'sunset': '19:09:50',
#    'sunsetEpoch': 1584832190,
#    'moonphase': 0.97,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [4.1, 9.8, 19.2],
#     'tempmin': [-4.1, 2.7, 14.0],
#     'feelslike': [-10.1, 9.8, 19.2],
#     'precip': [0.0, 4.9, 26.3],
#     'humidity': [33.7, 62.9, 94.9],
#     'snowdepth': [8.3, 8.3, 8.3],
#     'windspeed': [1.1, 22.3, 50.0],
#     'windgust': [40.0, 55.4, 79.6],
#     'winddir': [45.5, 181.8, 303.6],
#     'cloudcover': [0.0, 43.0, 99.5]},
#    'hours': None},
#   {'datetime': '2020-03-22',
#    'datetimeEpoch': 1584849600,
#    'tzoffset': -4.0,
#    'tempmax': 8.3,
#    'tempmin': 2.1,
#    'temp': 4.8,
#    'feelslikemax': 18.4,
#    'feelslikemin': 3.3,
#    'feelslike': 8.9,
#    'dew': -6.2,
#    'humidity': 46.11,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.4,
#    'windspeed': 27.5,
#    'winddir': 62.4,
#    'pressure': 1037.0,
#    'cloudcover': 35.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:10',
#    'sunriseEpoch': 1584874510,
#    'sunset': '19:10:53',
#    'sunsetEpoch': 1584918653,
#    'moonphase': 0.99,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [0.1, 10.8, 23.1],
#     'tempmin': [-5.6, 2.7, 13.3],
#     'feelslike': [-12.7, 10.8, 23.1],
#     'precip': [0.0, 4.2, 32.6],
#     'humidity': [22.0, 54.9, 92.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 21.6, 35.3],
#     'windgust': [42.5, 60.5, 81.4],
#     'winddir': [91.0, 254.6, 318.3],
#     'cloudcover': [0.0, 33.4, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-23',
#    'datetimeEpoch': 1584936000,
#    'tzoffset': -4.0,
#    'tempmax': 5.6,
#    'tempmin': 3.8,
#    'temp': 4.2,
#    'feelslikemax': 5.5,
#    'feelslikemin': -3.4,
#    'feelslike': 0.9,
#    'dew': 1.5,
#    'humidity': 83.21,
#    'precip': 17.42,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.7,
#    'windspeed': 34.2,
#    'winddir': 89.3,
#    'pressure': 1025.9,
#    'cloudcover': 46.2,
#    'visibility': 12.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:30',
#    'sunriseEpoch': 1584960810,
#    'sunset': '19:11:57',
#    'sunsetEpoch': 1585005117,
#    'moonphase': 1.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [3.3, 10.6, 24.0],
#     'tempmin': [-5.1, 2.2, 15.1],
#     'feelslike': [-10.1, 10.6, 24.0],
#     'precip': [0.0, 3.4, 21.8],
#     'humidity': [22.6, 49.1, 91.1],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 20.9, 42.5],
#     'windgust': [40.7, 57.6, 83.5],
#     'winddir': [62.0, 243.2, 317.3],
#     'cloudcover': [0.0, 24.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-24',
#    'datetimeEpoch': 1585022400,
#    'tzoffset': -4.0,
#    'tempmax': 14.2,
#    'tempmin': 3.3,
#    'temp': 8.1,
#    'feelslikemax': 5.6,
#    'feelslikemin': -1.9,
#    'feelslike': 0.3,
#    'dew': 1.6,
#    'humidity': 65.72,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 20.1,
#    'winddir': 166.8,
#    'pressure': 1019.7,
#    'cloudcover': 9.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:51',
#    'sunriseEpoch': 1585047111,
#    'sunset': '19:13:00',
#    'sunsetEpoch': 1585091580,
#    'moonphase': 0.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [0.7, 10.9, 18.0],
#     'tempmin': [-5.8, 2.6, 10.1],
#     'feelslike': [-8.6, 10.9, 18.0],
#     'precip': [0.0, 0.4, 2.9],
#     'humidity': [31.4, 47.7, 80.4],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 18.7, 33.5],
#     'windgust': [33.5, 42.1, 53.6],
#     'winddir': [72.6, 185.9, 287.1],
#     'cloudcover': [0.0, 30.5, 93.8]},
#    'hours': None},
#   {'datetime': '2020-03-25',
#    'datetimeEpoch': 1585108800,
#    'tzoffset': -4.0,
#    'tempmax': 7.2,
#    'tempmin': 5.6,
#    'temp': 6.4,
#    'feelslikemax': 14.2,
#    'feelslikemin': 0.1,
#    'feelslike': 6.7,
#    'dew': 1.8,
#    'humidity': 72.46,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.7,
#    'windspeed': 34.7,
#    'winddir': 39.1,
#    'pressure': 1018.4,
#    'cloudcover': 36.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:11',
#    'sunriseEpoch': 1585133411,
#    'sunset': '19:14:04',
#    'sunsetEpoch': 1585178044,
#    'moonphase': 0.01,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [2.2, 9.9, 21.7],
#     'tempmin': [-2.1, 3.5, 9.2],
#     'feelslike': [-7.0, 9.9, 21.7],
#     'precip': [0.0, 0.8, 5.5],
#     'humidity': [35.0, 55.2, 83.2],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 19.8, 37.1],
#     'windgust': [33.5, 56.2, 96.1],
#     'winddir': [46.6, 143.2, 286.0],
#     'cloudcover': [0.0, 34.2, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-26',
#    'datetimeEpoch': 1585195200,
#    'tzoffset': -4.0,
#    'tempmax': 15.5,
#    'tempmin': 4.3,
#    'temp': 8.9,
#    'feelslikemax': 4.0,
#    'feelslikemin': 1.4,
#    'feelslike': 2.8,
#    'dew': 1.8,
#    'humidity': 62.29,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 20.0,
#    'winddir': 193.8,
#    'pressure': 1015.4,
#    'cloudcover': 1.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:48:32',
#    'sunriseEpoch': 1585219712,
#    'sunset': '19:15:07',
#    'sunsetEpoch': 1585264507,
#    'moonphase': 0.02,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [1.2, 10.1, 18.9],
#     'tempmin': [-3.3, 2.7, 7.2],
#     'feelslike': [-8.9, 10.1, 18.9],
#     'precip': [0.0, 1.6, 8.1],
#     'humidity': [28.6, 59.4, 90.2],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.4, 19.8, 29.5],
#     'windgust': [27.7, 49.3, 63.0],
#     'winddir': [41.5, 161.8, 309.3],
#     'cloudcover': [0.0, 36.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-27',
#    'datetimeEpoch': 1585281600,
#    'tzoffset': -4.0,
#    'tempmax': 21.0,
#    'tempmin': 10.0,
#    'temp': 14.3,
#    'feelslikemax': 15.5,
#    'feelslikemin': 1.0,
#    'feelslike': 7.7,
#    'dew': 3.1,
#    'humidity': 52.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 16.2,
#    'winddir': 199.3,
#    'pressure': 1011.5,
#    'cloudcover': 19.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:46:53',
#    'sunriseEpoch': 1585306013,
#    'sunset': '19:16:10',
#    'sunsetEpoch': 1585350970,
#    'moonphase': 0.04,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [4.7, 11.2, 25.1],
#     'tempmin': [-5.1, 3.0, 10.7],
#     'feelslike': [-9.2, 11.2, 25.1],
#     'precip': [0.0, 1.8, 8.5],
#     'humidity': [19.6, 53.7, 89.4],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 16.9, 35.3],
#     'windgust': [27.7, 39.2, 60.8],
#     'winddir': [70.1, 196.8, 315.5],
#     'cloudcover': [0.0, 26.0, 99.9]},
#    'hours': None},
#   {'datetime': '2020-03-28',
#    'datetimeEpoch': 1585368000,
#    'tzoffset': -4.0,
#    'tempmax': 12.8,
#    'tempmin': 7.8,
#    'temp': 9.3,
#    'feelslikemax': 21.0,
#    'feelslikemin': 10.0,
#    'feelslike': 14.3,
#    'dew': 2.9,
#    'humidity': 67.86,
#    'precip': 0.54,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 25.6,
#    'winddir': 41.6,
#    'pressure': 1018.8,
#    'cloudcover': 34.7,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:14',
#    'sunriseEpoch': 1585392314,
#    'sunset': '19:17:13',
#    'sunsetEpoch': 1585437433,
#    'moonphase': 0.07,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [4.4, 11.6, 19.2],
#     'tempmin': [-2.8, 3.7, 9.0],
#     'feelslike': [-8.3, 11.6, 19.2],
#     'precip': [0.0, 5.8, 81.0],
#     'humidity': [32.2, 64.2, 100.0],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 20.9, 40.7],
#     'windgust': [35.3, 51.8, 64.8],
#     'winddir': [52.4, 169.3, 292.7],
#     'cloudcover': [0.0, 40.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-29',
#    'datetimeEpoch': 1585454400,
#    'tzoffset': -4.0,
#    'tempmax': 8.3,
#    'tempmin': 7.2,
#    'temp': 7.9,
#    'feelslikemax': 12.8,
#    'feelslikemin': 4.1,
#    'feelslike': 7.2,
#    'dew': 6.8,
#    'humidity': 92.8,
#    'precip': 0.71,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.7,
#    'windspeed': 34.9,
#    'winddir': 32.7,
#    'pressure': 1013.9,
#    'cloudcover': 52.8,
#    'visibility': 6.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:43:35',
#    'sunriseEpoch': 1585478615,
#    'sunset': '19:18:16',
#    'sunsetEpoch': 1585523896,
#    'moonphase': 0.11,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [7.2, 12.9, 20.1],
#     'tempmin': [-3.8, 5.2, 11.1],
#     'feelslike': [-9.4, 12.9, 20.1],
#     'precip': [0.0, 5.5, 46.2],
#     'humidity': [19.3, 59.8, 96.5],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.4, 21.6, 37.1],
#     'windgust': [29.5, 57.6, 72.0],
#     'winddir': [74.0, 202.5, 319.2],
#     'cloudcover': [0.0, 35.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-30',
#    'datetimeEpoch': 1585540800,
#    'tzoffset': -4.0,
#    'tempmax': 10.0,
#    'tempmin': 6.6,
#    'temp': 8.3,
#    'feelslikemax': 5.5,
#    'feelslikemin': 2.7,
#    'feelslike': 4.4,
#    'dew': 6.0,
#    'humidity': 85.17,
#    'precip': 1.21,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 20.0,
#    'winddir': 99.1,
#    'pressure': 1014.2,
#    'cloudcover': 48.5,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:41:56',
#    'sunriseEpoch': 1585564916,
#    'sunset': '19:19:19',
#    'sunsetEpoch': 1585610359,
#    'moonphase': 0.15,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.7, 13.0, 21.7],
#     'tempmin': [-2.1, 4.8, 10.5],
#     'feelslike': [-7.3, 13.0, 21.7],
#     'precip': [0.0, 6.9, 63.0],
#     'humidity': [19.4, 56.9, 98.6],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.1, 20.5, 42.5],
#     'windgust': [31.7, 52.9, 76.0],
#     'winddir': [36.4, 180.5, 309.5],
#     'cloudcover': [0.0, 35.2, 100.0]},
#    'hours': None},
#   {'datetime': '2020-03-31',
#    'datetimeEpoch': 1585627200,
#    'tzoffset': -4.0,
#    'tempmax': 7.9,
#    'tempmin': 5.6,
#    'temp': 6.6,
#    'feelslikemax': 10.0,
#    'feelslikemin': 3.6,
#    'feelslike': 6.9,
#    'dew': 3.3,
#    'humidity': 79.29,
#    'precip': 1.01,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 23.7,
#    'winddir': 113.5,
#    'pressure': 1016.1,
#    'cloudcover': 49.3,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:40:17',
#    'sunriseEpoch': 1585651217,
#    'sunset': '19:20:22',
#    'sunsetEpoch': 1585696822,
#    'moonphase': 0.2,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.7, 12.4, 22.9],
#     'tempmin': [-0.6, 5.0, 10.9],
#     'feelslike': [-6.3, 12.4, 22.9],
#     'precip': [0.0, 5.7, 32.2],
#     'humidity': [28.6, 63.5, 99.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.1, 20.5, 40.0],
#     'windgust': [37.1, 51.1, 59.8],
#     'winddir': [56.3, 175.0, 314.3],
#     'cloudcover': [0.0, 44.8, 100.0]},
#    'hours': None},
#   {'datetime': '2020-04-01',
#    'datetimeEpoch': 1585713600,
#    'tzoffset': -4.0,
#    'tempmax': 14.3,
#    'tempmin': 4.3,
#    'temp': 8.8,
#    'feelslikemax': 7.2,
#    'feelslikemin': 1.5,
#    'feelslike': 4.4,
#    'dew': -0.4,
#    'humidity': 54.57,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.8,
#    'windspeed': 28.9,
#    'winddir': 115.5,
#    'pressure': 1009.2,
#    'cloudcover': 30.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:38:39',
#    'sunriseEpoch': 1585737519,
#    'sunset': '19:21:25',
#    'sunsetEpoch': 1585783285,
#    'moonphase': 0.25,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [6.2, 13.1, 25.7],
#     'tempmin': [-1.1, 6.0, 13.4],
#     'feelslike': [-5.3, 13.1, 25.7],
#     'precip': [0.0, 2.4, 9.8],
#     'humidity': [40.4, 68.7, 98.1],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 19.4, 42.1],
#     'windgust': [37.1, 56.5, 76.0],
#     'winddir': [55.0, 180.1, 283.6],
#     'cloudcover': [0.0, 53.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-04-02',
#    'datetimeEpoch': 1585800000,
#    'tzoffset': -4.0,
#    'tempmax': 16.0,
#    'tempmin': 4.3,
#    'temp': 10.1,
#    'feelslikemax': 14.3,
#    'feelslikemin': 0.2,
#    'feelslike': 7.1,
#    'dew': -1.4,
#    'humidity': 45.89,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 54.3,
#    'windspeed': 13.2,
#    'winddir': 320.2,
#    'pressure': 1005.6,
#    'cloudcover': 26.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:37:01',
#    'sunriseEpoch': 1585823821,
#    'sunset': '19:22:28',
#    'sunsetEpoch': 1585869748,
#    'moonphase': 0.31,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [6.1, 13.3, 19.3],
#     'tempmin': [0.7, 5.2, 9.4],
#     'feelslike': [-3.5, 13.3, 19.3],
#     'precip': [0.0, 2.9, 45.9],
#     'humidity': [31.7, 62.1, 99.1],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 20.5, 35.3],
#     'windgust': [40.7, 54.7, 79.6],
#     'winddir': [57.5, 165.7, 295.5],
#     'cloudcover': [0.0, 37.3, 100.0]},
#    'hours': None},
#   {'datetime': '2020-04-03',
#    'datetimeEpoch': 1585886400,
#    'tzoffset': -4.0,
#    'tempmax': 11.6,
#    'tempmin': 7.8,
#    'temp': 10.2,
#    'feelslikemax': 16.0,
#    'feelslikemin': 2.9,
#    'feelslike': 9.5,
#    'dew': 4.5,
#    'humidity': 68.24,
#    'precip': 0.42,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 25.8,
#    'winddir': 257.7,
#    'pressure': 1005.7,
#    'cloudcover': 34.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:35:23',
#    'sunriseEpoch': 1585910123,
#    'sunset': '19:23:31',
#    'sunsetEpoch': 1585956211,
#    'moonphase': 0.36,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.7, 13.6, 23.9],
#     'tempmin': [1.2, 5.8, 14.7],
#     'feelslike': [-4.7, 13.6, 23.9],
#     'precip': [0.0, 2.6, 23.3],
#     'humidity': [25.9, 59.5, 91.0],
#     'snowdepth': [58.0, 58.0, 58.0],
#     'windspeed': [0.4, 19.1, 33.5],
#     'windgust': [40.7, 61.2, 81.4],
#     'winddir': [83.0, 192.4, 294.7],
#     'cloudcover': [0.0, 41.3, 99.6]},
#    'hours': None},
#   {'datetime': '2020-04-04',
#    'datetimeEpoch': 1585972800,
#    'tzoffset': -4.0,
#    'tempmax': 16.1,
#    'tempmin': 8.3,
#    'temp': 10.9,
#    'feelslikemax': 11.6,
#    'feelslikemin': 6.1,
#    'feelslike': 9.9,
#    'dew': 5.8,
#    'humidity': 71.79,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 18.4,
#    'winddir': 134.4,
#    'pressure': 1015.4,
#    'cloudcover': 41.8,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:33:46',
#    'sunriseEpoch': 1585996426,
#    'sunset': '19:24:33',
#    'sunsetEpoch': 1586042673,
#    'moonphase': 0.41,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.9, 12.7, 24.0],
#     'tempmin': [-0.6, 5.2, 9.0],
#     'feelslike': [-4.2, 12.7, 24.0],
#     'precip': [0.0, 5.1, 34.3],
#     'humidity': [24.1, 62.8, 96.5],
#     'snowdepth': [None, None, None],
#     'windspeed': [11.5, 24.1, 40.7],
#     'windgust': [33.5, 57.2, 72.0],
#     'winddir': [46.9, 177.3, 299.0],
#     'cloudcover': [0.0, 49.7, 100.0]},
#    'hours': None},
#   {'datetime': '2020-04-05',
#    'datetimeEpoch': 1586059200,
#    'tzoffset': -4.0,
#    'tempmax': 18.3,
#    'tempmin': 7.9,
#    'temp': 11.4,
#    'feelslikemax': 16.1,
#    'feelslikemin': 5.9,
#    'feelslike': 10.0,
#    'dew': 7.2,
#    'humidity': 75.87,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.3,
#    'winddir': 134.8,
#    'pressure': 1016.8,
#    'cloudcover': 33.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:32:09',
#    'sunriseEpoch': 1586082729,
#    'sunset': '19:25:36',
#    'sunsetEpoch': 1586129136,
#    'moonphase': 0.45,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.7, 12.8, 23.3],
#     'tempmin': [-3.3, 4.3, 14.0],
#     'feelslike': [-10.0, 12.8, 23.3],
#     'precip': [0.0, 0.8, 4.7],
#     'humidity': [32.9, 51.0, 98.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [1.1, 22.3, 44.6],
#     'windgust': [31.7, 56.5, 79.6],
#     'winddir': [54.4, 215.3, 308.3],
#     'cloudcover': [0.0, 31.1, 100.0]},
#    'hours': None},
#   {'datetime': '2020-04-06',
#    'datetimeEpoch': 1586145600,
#    'tzoffset': -4.0,
#    'tempmax': 19.8,
#    'tempmin': 10.0,
#    'temp': 14.0,
#    'feelslikemax': 18.3,
#    'feelslikemin': 6.9,
#    'feelslike': 11.3,
#    'dew': 2.1,
#    'humidity': 50.4,
#    'precip': 0.1,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 21.8,
#    'winddir': 170.1,
#    'pressure': 1015.9,
#    'cloudcover': 11.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:30:33',
#    'sunriseEpoch': 1586169033,
#    'sunset': '19:26:39',
#    'sunsetEpoch': 1586215599,
#    'moonphase': 0.48,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [5.1, 13.2, 25.1],
#     'tempmin': [-1.1, 4.5, 15.9],
#     'feelslike': [-5.4, 13.2, 25.1],
#     'precip': [0.0, 1.9, 14.3],
#     'humidity': [24.7, 54.9, 88.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 21.2, 44.6],
#     'windgust': [25.9, 47.5, 68.4],
#     'winddir': [57.5, 194.8, 299.0],
#     'cloudcover': [0.0, 27.5, 90.4]},
#    'hours': None},
#   {'datetime': '2020-04-07',
#    'datetimeEpoch': 1586232000,
#    'tzoffset': -4.0,
#    'tempmax': 18.9,
#    'tempmin': 10.1,
#    'temp': 14.0,
#    'feelslikemax': 19.8,
#    'feelslikemin': 8.5,
#    'feelslike': 13.8,
#    'dew': 0.6,
#    'humidity': 41.77,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 21.9,
#    'winddir': 183.3,
#    'pressure': 1011.9,
#    'cloudcover': 19.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:28:56',
#    'sunriseEpoch': 1586255336,
#    'sunset': '19:27:42',
#    'sunsetEpoch': 1586302062,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [3.4, 14.0, 32.2],
#     'tempmin': [-1.1, 5.9, 13.3],
#     'feelslike': [-7.9, 14.0, 30.1],
#     'precip': [0.0, 1.5, 13.2],
#     'humidity': [27.9, 58.2, 82.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [9.7, 20.9, 33.5],
#     'windgust': [35.3, 58.0, 80.6],
#     'winddir': [46.2, 181.8, 323.3],
#     'cloudcover': [0.0, 41.3, 99.6]},
#    'hours': None},
#   {'datetime': '2020-04-08',
#    'datetimeEpoch': 1586318400,
#    'tzoffset': -4.0,
#    'tempmax': 19.2,
#    'tempmin': 9.4,
#    'temp': 13.9,
#    'feelslikemax': 18.9,
#    'feelslikemin': 10.1,
#    'feelslike': 14.0,
#    'dew': 8.7,
#    'humidity': 72.38,
#    'precip': 2.42,
# ...
#    'winddir': 71.4,
#    'pressure': 1030.3,
#    'cloudcover': 1.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:34:12',
#    'sunriseEpoch': 1589967252,
#    'sunset': '20:11:34',
#    'sunsetEpoch': 1590019894,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [12.9, 21.9, 28.3],
#     'tempmin': [6.7, 12.7, 19.9],
#     'feelslike': [4.2, 21.9, 28.7],
#     'precip': [0.0, 1.3, 11.5],
#     'humidity': [35.3, 60.3, 91.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 16.9, 31.7],
#     'windgust': [46.4, 74.5, 94.3],
#     'winddir': [60.0, 198.5, 301.2],
#     'cloudcover': [0.0, 27.3, 77.0]},
#    'hours': None},
#   {'datetime': '2020-05-21',
#    'datetimeEpoch': 1590033600,
#    'tzoffset': -4.0,
#    'tempmax': 19.3,
#    'tempmin': 9.9,
#    'temp': 14.2,
#    'feelslikemax': 18.8,
#    'feelslikemin': 10.6,
#    'feelslike': 14.1,
#    'dew': 7.6,
#    'humidity': 65.74,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 25.9,
#    'windspeed': 14.8,
#    'winddir': 109.4,
#    'pressure': 1028.7,
#    'cloudcover': 3.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:33:25',
#    'sunriseEpoch': 1590053605,
#    'sunset': '20:12:28',
#    'sunsetEpoch': 1590106348,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [13.9, 21.5, 29.0],
#     'tempmin': [6.2, 13.0, 18.3],
#     'feelslike': [4.7, 21.5, 29.3],
#     'precip': [0.0, 3.2, 35.8],
#     'humidity': [34.5, 61.9, 93.8],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 15.8, 24.1],
#     'windgust': [31.7, 68.8, 104.0],
#     'winddir': [65.5, 182.4, 297.1],
#     'cloudcover': [0.0, 34.7, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-22',
#    'datetimeEpoch': 1590120000,
#    'tzoffset': -4.0,
#    'tempmax': 24.3,
#    'tempmin': 13.3,
#    'temp': 17.8,
#    'feelslikemax': 19.3,
#    'feelslikemin': 8.2,
#    'feelslike': 14.0,
#    'dew': 13.4,
#    'humidity': 76.94,
#    'precip': 0.04,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 14.9,
#    'winddir': 133.9,
#    'pressure': 1021.1,
#    'cloudcover': 26.7,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:32:41',
#    'sunriseEpoch': 1590139961,
#    'sunset': '20:13:22',
#    'sunsetEpoch': 1590192802,
#    'moonphase': 1.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [13.4, 20.3, 29.0],
#     'tempmin': [7.9, 13.1, 17.9],
#     'feelslike': [6.0, 20.3, 30.1],
#     'precip': [0.0, 3.3, 25.0],
#     'humidity': [41.3, 70.8, 97.3],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 15.5, 27.7],
#     'windgust': [33.5, 69.5, 116.6],
#     'winddir': [50.9, 148.4, 288.9],
#     'cloudcover': [0.0, 39.8, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-23',
#    'datetimeEpoch': 1590206400,
#    'tzoffset': -4.0,
#    'tempmax': 19.3,
#    'tempmin': 13.8,
#    'temp': 16.3,
#    'feelslikemax': 24.3,
#    'feelslikemin': 13.3,
#    'feelslike': 17.8,
#    'dew': 14.1,
#    'humidity': 87.27,
#    'precip': 8.0,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.1,
#    'windspeed': 35.3,
#    'winddir': 54.5,
#    'pressure': 1016.8,
#    'cloudcover': 49.4,
#    'visibility': 11.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:31:58',
#    'sunriseEpoch': 1590226318,
#    'sunset': '20:14:14',
#    'sunsetEpoch': 1590279254,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [13.4, 21.3, 30.7],
#     'tempmin': [7.2, 13.0, 18.2],
#     'feelslike': [5.5, 21.3, 33.9],
#     'precip': [0.0, 5.3, 45.6],
#     'humidity': [34.4, 72.0, 97.5],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 16.9, 28.4],
#     'windgust': [40.0, 83.5, 126.0],
#     'winddir': [51.1, 158.6, 295.7],
#     'cloudcover': [0.0, 33.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-24',
#    'datetimeEpoch': 1590292800,
#    'tzoffset': -4.0,
#    'tempmax': 21.1,
#    'tempmin': 12.1,
#    'temp': 15.6,
#    'feelslikemax': 19.3,
#    'feelslikemin': 13.8,
#    'feelslike': 16.3,
#    'dew': 9.3,
#    'humidity': 66.51,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 29.6,
#    'winddir': 73.8,
#    'pressure': 1024.0,
#    'cloudcover': 39.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:31:17',
#    'sunriseEpoch': 1590312677,
#    'sunset': '20:15:06',
#    'sunsetEpoch': 1590365706,
#    'moonphase': 0.02,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [13.4, 22.4, 29.0],
#     'tempmin': [8.6, 14.0, 18.9],
#     'feelslike': [5.6, 22.4, 28.9],
#     'precip': [0.0, 5.4, 49.1],
#     'humidity': [39.8, 70.8, 97.9],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 17.3, 31.7],
#     'windgust': [29.5, 69.8, 107.3],
#     'winddir': [57.9, 168.8, 283.8],
#     'cloudcover': [0.0, 41.9, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-25',
#    'datetimeEpoch': 1590379200,
#    'tzoffset': -4.0,
#    'tempmax': 22.7,
#    'tempmin': 13.4,
#    'temp': 17.0,
#    'feelslikemax': 21.1,
#    'feelslikemin': 12.1,
#    'feelslike': 15.6,
#    'dew': 13.0,
#    'humidity': 78.22,
#    'precip': 0.14,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.5,
#    'winddir': 96.9,
#    'pressure': 1023.3,
#    'cloudcover': 35.8,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:30:37',
#    'sunriseEpoch': 1590399037,
#    'sunset': '20:15:57',
#    'sunsetEpoch': 1590452157,
#    'moonphase': 0.04,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [11.9, 22.8, 31.9],
#     'tempmin': [7.9, 14.2, 18.2],
#     'feelslike': [6.3, 22.8, 30.3],
#     'precip': [0.0, 1.1, 6.8],
#     'humidity': [39.7, 65.0, 93.0],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 18.4, 37.1],
#     'windgust': [31.7, 54.0, 86.8],
#     'winddir': [56.6, 186.3, 307.1],
#     'cloudcover': [0.0, 25.6, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-26',
#    'datetimeEpoch': 1590465600,
#    'tzoffset': -4.0,
#    'tempmax': 23.9,
#    'tempmin': 14.4,
#    'temp': 18.1,
#    'feelslikemax': 22.7,
#    'feelslikemin': 13.4,
#    'feelslike': 17.0,
#    'dew': 14.8,
#    'humidity': 82.04,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 85.0,
#    'windspeed': 14.9,
#    'winddir': 178.1,
#    'pressure': 1023.2,
#    'cloudcover': 25.3,
#    'visibility': 11.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:30:00',
#    'sunriseEpoch': 1590485400,
#    'sunset': '20:16:47',
#    'sunsetEpoch': 1590538607,
#    'moonphase': 0.07,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [12.9, 24.0, 33.0],
#     'tempmin': [9.7, 15.8, 22.2],
#     'feelslike': [9.7, 24.0, 34.0],
#     'precip': [0.0, 2.9, 38.5],
#     'humidity': [36.3, 67.3, 96.3],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 17.3, 38.9],
#     'windgust': [33.5, 54.4, 83.2],
#     'winddir': [52.5, 183.9, 301.8],
#     'cloudcover': [0.0, 33.0, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-27',
#    'datetimeEpoch': 1590552000,
#    'tzoffset': -4.0,
#    'tempmax': 24.3,
#    'tempmin': 15.0,
#    'temp': 18.6,
#    'feelslikemax': 23.9,
#    'feelslikemin': 14.4,
#    'feelslike': 18.1,
#    'dew': 15.4,
#    'humidity': 82.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.7,
#    'winddir': 137.6,
#    'pressure': 1023.7,
#    'cloudcover': 31.4,
#    'visibility': 13.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:29:25',
#    'sunriseEpoch': 1590571765,
#    'sunset': '20:17:36',
#    'sunsetEpoch': 1590625056,
#    'moonphase': 0.11,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [18.2, 25.3, 30.1],
#     'tempmin': [10.7, 16.1, 23.4],
#     'feelslike': [10.7, 25.3, 30.9],
#     'precip': [0.0, 2.8, 18.4],
#     'humidity': [38.0, 69.0, 91.7],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 16.2, 36.4],
#     'windgust': [46.4, 67.0, 100.1],
#     'winddir': [60.0, 160.2, 286.3],
#     'cloudcover': [0.0, 35.6, 90.4]},
#    'hours': None},
#   {'datetime': '2020-05-28',
#    'datetimeEpoch': 1590638400,
#    'tzoffset': -4.0,
#    'tempmax': 23.9,
#    'tempmin': 16.8,
#    'temp': 20.1,
#    'feelslikemax': 24.3,
#    'feelslikemin': 15.0,
#    'feelslike': 18.6,
#    'dew': 17.8,
#    'humidity': 86.89,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.5,
#    'windspeed': 20.6,
#    'winddir': 127.5,
#    'pressure': 1021.3,
#    'cloudcover': 44.2,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:28:51',
#    'sunriseEpoch': 1590658131,
#    'sunset': '20:18:24',
#    'sunsetEpoch': 1590711504,
#    'moonphase': 0.16,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [16.2, 24.0, 32.2],
#     'tempmin': [11.7, 16.3, 21.7],
#     'feelslike': [11.7, 24.0, 33.6],
#     'precip': [0.0, 2.1, 13.4],
#     'humidity': [38.1, 69.9, 93.4],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 14.8, 22.3],
#     'windgust': [37.1, 63.7, 81.7],
#     'winddir': [60.0, 170.8, 310.0],
#     'cloudcover': [0.0, 31.5, 100.0]},
#    'hours': None},
#   {'datetime': '2020-05-29',
#    'datetimeEpoch': 1590724800,
#    'tzoffset': -4.0,
#    'tempmax': 27.2,
#    'tempmin': 18.9,
#    'temp': 22.9,
#    'feelslikemax': 23.9,
#    'feelslikemin': 16.8,
#    'feelslike': 20.1,
#    'dew': 19.2,
#    'humidity': 80.54,
#    'precip': 0.25,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 18.4,
#    'winddir': 142.2,
#    'pressure': 1015.3,
#    'cloudcover': 38.1,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:28:19',
#    'sunriseEpoch': 1590744499,
#    'sunset': '20:19:11',
#    'sunsetEpoch': 1590797951,
#    'moonphase': 0.21,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [15.3, 25.1, 31.2],
#     'tempmin': [10.7, 15.9, 21.7],
#     'feelslike': [10.7, 25.1, 33.5],
#     'precip': [0.0, 2.1, 16.2],
#     'humidity': [33.4, 66.6, 87.7],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 14.0, 24.1],
#     'windgust': [29.5, 42.1, 64.8],
#     'winddir': [40.0, 182.7, 309.2],
#     'cloudcover': [0.0, 22.0, 86.8]},
#    'hours': None},
#   {'datetime': '2020-05-30',
#    'datetimeEpoch': 1590811200,
#    'tzoffset': -4.0,
#    'tempmax': 28.3,
#    'tempmin': 19.4,
#    'temp': 23.5,
#    'feelslikemax': 28.5,
#    'feelslikemin': 18.9,
#    'feelslike': 23.1,
#    'dew': 13.8,
#    'humidity': 58.76,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 18.4,
#    'winddir': 254.7,
#    'pressure': 1012.0,
#    'cloudcover': 18.2,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:27:50',
#    'sunriseEpoch': 1590830870,
#    'sunset': '20:19:57',
#    'sunsetEpoch': 1590884397,
#    'moonphase': 0.27,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [15.1, 25.3, 31.9],
#     'tempmin': [10.7, 16.7, 22.1],
#     'feelslike': [10.7, 25.3, 32.0],
#     'precip': [0.0, 3.9, 41.9],
#     'humidity': [37.0, 64.2, 91.6],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.4, 14.0, 24.1],
#     'windgust': [35.3, 53.3, 72.0],
#     'winddir': [70.7, 190.0, 300.0],
#     'cloudcover': [0.0, 20.5, 73.8]},
#    'hours': None},
#   {'datetime': '2020-05-31',
#    'datetimeEpoch': 1590897600,
#    'tzoffset': -4.0,
#    'tempmax': 22.7,
#    'tempmin': 14.3,
#    'temp': 18.4,
#    'feelslikemax': 22.7,
#    'feelslikemin': 14.3,
#    'feelslike': 18.6,
#    'dew': 4.1,
#    'humidity': 39.84,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.1,
#    'windspeed': 16.5,
#    'winddir': 327.0,
#    'pressure': 1018.0,
#    'cloudcover': 7.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '05:27:22',
#    'sunriseEpoch': 1590917242,
#    'sunset': '20:20:41',
#    'sunsetEpoch': 1590970841,
#    'moonphase': 0.33,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KLGA',
#     'KJRB',
#     'KNYC',
#     '72503014732'],
#    'source': 'obs',
#    'normal': {'tempmax': [17.9, 26.0, 33.0],
#     'tempmin': [10.7, 17.5, 23.1],
#     'feelslike': [10.7, 26.0, 32.5],
#     'precip': [0.0, 4.0, 37.3],
#     'humidity': [38.6, 65.7, 89.2],
#     'snowdepth': [None, None, None],
#     'windspeed': [0.7, 15.8, 27.7],
#     'windgust': [27.7, 49.3, 83.2],
#     'winddir': [60.1, 171.0, 296.4],
#     'cloudcover': [0.0, 20.2, 66.3]},
#    'hours': None}],
#  'stations': {'72505394728': {'distance': 7846.0,
#    'latitude': 40.779,
#    'longitude': -73.969,
#    'useCount': 0,
#    'id': '72505394728',
#    'name': 'NY CITY CENTRAL PARK, NY US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72055399999': {'distance': 1500.0,
#    'latitude': 40.701,
#    'longitude': -74.009,
#    'useCount': 0,
#    'id': '72055399999',
#    'name': 'PORT AUTH DOWNTN MANHATTAN WALL ST HEL, NY US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KLGA': {'distance': 10937.0,
#    'latitude': 40.77,
#    'longitude': -73.9,
#    'useCount': 0,
#    'id': 'KLGA',
#    'name': 'KLGA',
#    'quality': 100,
#    'contribution': 0.0},
#   'KJRB': {'distance': 1500.0,
#    'latitude': 40.701,
#    'longitude': -74.009,
#    'useCount': 0,
#    'id': 'KJRB',
#    'name': 'Downtown Manhattan/wall St, New York',
#    'quality': 100,
#    'contribution': 0.0},
#   'KNYC': {'distance': 6577.0,
#    'latitude': 40.77,
#    'longitude': -73.98,
#    'useCount': 0,
#    'id': 'KNYC',
#    'name': 'KNYC',
#    'quality': 100,
#    'contribution': 0.0},
#   '72503014732': {'distance': 12899.0,
#    'latitude': 40.779,
#    'longitude': -73.88,
#    'useCount': 0,
#    'id': '72503014732',
#    'name': 'LAGUARDIA AIRPORT, NY US',
#    'quality': 100,
#    'contribution': 0.0}}}

# %%
weather.keys()
# Out:
# dict_keys(['queryCost', 'latitude', 'longitude', 'resolvedAddress', 'address', 'timezone', 'tzoffset', 'days', 'stations'])

# %%
weather['days']
# Out:
# [{'datetime': '2020-03-01',
#   'datetimeEpoch': 1583038800,
#   'tempmax': 8.7,
#   'tempmin': -2.9,
#   'temp': 2.4,
#   'feelslikemax': 8.0,
#   'feelslikemin': -7.4,
#   'feelslike': -0.4,
#   'dew': -8.4,
#   'humidity': 46.32,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 64.8,
#   'windspeed': 22.0,
#   'winddir': 280.6,
#   'pressure': 1020.4,
#   'cloudcover': 4.6,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:29:07',
#   'sunriseEpoch': 1583062147,
#   'sunset': '17:47:57',
#   'sunsetEpoch': 1583102877,
#   'moonphase': 0.18,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-1.1, 7.4, 19.6],
#    'tempmin': [-8.3, 1.3, 11.8],
#    'feelslike': [-14.1, 7.4, 19.6],
#    'precip': [0.0, 2.9, 12.1],
#    'humidity': [25.7, 58.1, 90.7],
#    'snowdepth': [11.3, 11.3, 11.3],
#    'windspeed': [0.7, 19.8, 33.5],
#    'windgust': [31.7, 56.9, 70.9],
#    'winddir': [45.6, 199.6, 308.8],
#    'cloudcover': [0.0, 35.7, 99.1]},
#   'hours': None},
#  {'datetime': '2020-03-02',
#   'datetimeEpoch': 1583125200,
#   'tempmax': 14.3,
#   'tempmin': 3.9,
#   'temp': 9.1,
#   'feelslikemax': 14.3,
#   'feelslikemin': 1.8,
#   'feelslike': 8.4,
#   'dew': 0.0,
#   'humidity': 53.31,
#   'precip': 0.24,
#   'precipprob': None,
#   'precipcover': 4.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 61.3,
#   'windspeed': 23.4,
#   'winddir': 239.9,
#   'pressure': 1014.9,
#   'cloudcover': 14.5,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:27:35',
#   'sunriseEpoch': 1583148455,
#   'sunset': '17:49:05',
#   'sunsetEpoch': 1583189345,
#   'moonphase': 0.23,
#   'conditions': 'Rain',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-2.8, 7.5, 19.4],
#    'tempmin': [-8.8, 0.1, 6.2],
#    'feelslike': [-17.1, 7.5, 19.4],
#    'precip': [0.0, 8.7, 62.8],
#    'humidity': [37.6, 62.7, 89.9],
#    'snowdepth': [14.5, 14.5, 14.5],
#    'windspeed': [0.7, 23.0, 38.9],
#    'windgust': [37.1, 51.8, 65.9],
#    'winddir': [104.0, 231.0, 304.7],
#    'cloudcover': [0.0, 47.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-03',
#   'datetimeEpoch': 1583211600,
#   'tempmax': 14.8,
#   'tempmin': 8.9,
#   'temp': 11.1,
#   'feelslikemax': 14.8,
#   'feelslikemin': 7.8,
#   'feelslike': 10.8,
#   'dew': 7.1,
#   'humidity': 77.41,
#   'precip': 7.93,
#   'precipprob': None,
#   'precipcover': 33.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 85.0,
#   'windspeed': 14.7,
#   'winddir': 213.8,
#   'pressure': 1004.4,
#   'cloudcover': 23.4,
#   'visibility': 14.3,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:26:01',
#   'sunriseEpoch': 1583234761,
#   'sunset': '17:50:13',
#   'sunsetEpoch': 1583275813,
#   'moonphase': 0.28,
#   'conditions': 'Rain',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-3.1, 6.4, 16.2],
#    'tempmin': [-11.1, -0.9, 8.4],
#    'feelslike': [-21.2, 6.4, 16.2],
#    'precip': [0.0, 2.9, 24.9],
#    'humidity': [32.4, 54.3, 78.2],
#    'snowdepth': [12.3, 12.3, 12.3],
#    'windspeed': [1.1, 22.3, 44.6],
#    'windgust': [31.7, 48.6, 68.4],
#    'winddir': [115.5, 226.1, 314.7],
#    'cloudcover': [0.0, 26.9, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-04',
#   'datetimeEpoch': 1583298000,
#   'tempmax': 13.8,
#   'tempmin': 7.2,
#   'temp': 10.2,
#   'feelslikemax': 13.8,
#   'feelslikemin': 3.2,
#   'feelslike': 8.9,
#   'dew': -0.2,
#   'humidity': 50.65,
#   'precip': 0.97,
#   'precipprob': None,
#   'precipcover': 12.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 79.8,
#   'windspeed': 39.6,
#   'winddir': 270.9,
#   'pressure': 1007.2,
#   'cloudcover': 7.1,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:24:28',
#   'sunriseEpoch': 1583321068,
#   'sunset': '17:51:20',
#   'sunsetEpoch': 1583362280,
#   'moonphase': 0.34,
#   'conditions': 'Rain',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-2.1, 5.5, 17.2],
#    'tempmin': [-10.3, -1.5, 7.2],
#    'feelslike': [-14.4, 5.5, 17.2],
#    'precip': [0.0, 1.7, 9.5],
#    'humidity': [40.9, 57.8, 89.9],
#    'snowdepth': [12.5, 12.5, 12.5],
#    'windspeed': [0.7, 19.8, 37.1],
#    'windgust': [35.3, 54.7, 75.6],
#    'winddir': [71.0, 218.8, 309.6],
#    'cloudcover': [0.0, 41.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-05',
#   'datetimeEpoch': 1583384400,
#   'tempmax': 12.1,
#   'tempmin': 4.3,
#   'temp': 7.6,
#   'feelslikemax': 12.1,
#   'feelslikemin': 2.3,
#   'feelslike': 6.5,
#   'dew': -2.1,
#   'humidity': 51.97,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 73.8,
#   'windspeed': 14.1,
#   'winddir': 254.4,
#   'pressure': 1018.8,
#   'cloudcover': 1.9,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:22:53',
#   'sunriseEpoch': 1583407373,
#   'sunset': '17:52:27',
#   'sunsetEpoch': 1583448747,
#   'moonphase': 0.38,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [0.1, 6.3, 15.1],
#    'tempmin': [-8.6, -1.5, 6.7],
#    'feelslike': [-14.2, 6.3, 15.1],
#    'precip': [0.0, 2.3, 16.8],
#    'humidity': [31.6, 55.6, 99.8],
#    'snowdepth': [17.9, 17.9, 17.9],
#    'windspeed': [0.7, 20.9, 37.1],
#    'windgust': [35.3, 52.9, 68.4],
#    'winddir': [92.3, 212.7, 298.6],
#    'cloudcover': [0.0, 36.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-06',
#   'datetimeEpoch': 1583470800,
#   'tempmax': 7.8,
#   'tempmin': 3.8,
#   'temp': 5.5,
#   'feelslikemax': 5.2,
#   'feelslikemin': -0.5,
#   'feelslike': 2.9,
#   'dew': 2.2,
#   'humidity': 79.77,
#   'precip': 4.17,
#   'precipprob': None,
#   'precipcover': 37.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 37.1,
#   'windspeed': 25.6,
#   'winddir': 82.2,
#   'pressure': 1012.8,
#   'cloudcover': 28.2,
#   'visibility': 14.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:21:18',
#   'sunriseEpoch': 1583493678,
#   'sunset': '17:53:34',
#   'sunsetEpoch': 1583535214,
#   'moonphase': 0.43,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-6.0, 6.5, 16.7],
#    'tempmin': [-11.0, -1.0, 10.1],
#    'feelslike': [-20.7, 6.5, 16.7],
#    'precip': [0.0, 4.0, 51.3],
#    'humidity': [26.1, 56.4, 97.6],
#    'snowdepth': [20.8, 20.8, 20.8],
#    'windspeed': [0.7, 19.8, 38.9],
#    'windgust': [29.5, 59.8, 74.2],
#    'winddir': [64.5, 181.9, 298.3],
#    'cloudcover': [0.0, 28.8, 97.1]},
#   'hours': None},
#  {'datetime': '2020-03-07',
#   'datetimeEpoch': 1583557200,
#   'tempmax': 11.0,
#   'tempmin': 3.3,
#   'temp': 5.9,
#   'feelslikemax': 11.0,
#   'feelslikemin': 1.1,
#   'feelslike': 4.4,
#   'dew': -5.8,
#   'humidity': 49.3,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 55.3,
#   'windspeed': 13.0,
#   'winddir': 304.5,
#   'pressure': 1021.9,
#   'cloudcover': 16.7,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:19:43',
#   'sunriseEpoch': 1583579983,
#   'sunset': '17:54:41',
#   'sunsetEpoch': 1583621681,
#   'moonphase': 0.46,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-5.8, 8.6, 21.2],
#    'tempmin': [-11.0, 0.2, 10.9],
#    'feelslike': [-16.2, 8.6, 21.2],
#    'precip': [0.0, 3.9, 30.8],
#    'humidity': [35.3, 59.9, 92.6],
#    'snowdepth': [15.3, 15.3, 15.3],
#    'windspeed': [0.7, 19.8, 31.7],
#    'windgust': [38.9, 51.8, 59.4],
#    'winddir': [61.0, 182.6, 277.9],
#    'cloudcover': [0.0, 24.6, 69.2]},
#   'hours': None},
#  {'datetime': '2020-03-08',
#   'datetimeEpoch': 1583643600,
#   'tempmax': 15.0,
#   'tempmin': 2.2,
#   'temp': 8.1,
#   'feelslikemax': 0.0,
#   'feelslikemin': 0.0,
#   'feelslike': None,
#   'dew': -5.8,
#   'humidity': 37.85,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 93.2,
#   'windspeed': 18.2,
#   'winddir': 261.9,
#   'pressure': 1029.9,
#   'cloudcover': 9.1,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:18:07',
#   'sunriseEpoch': 1583666287,
#   'sunset': '18:55:47',
#   'sunsetEpoch': 1583708147,
#   'moonphase': 0.49,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [1.2, 9.9, 21.2],
#    'tempmin': [-8.3, 1.5, 11.9],
#    'feelslike': [-16.1, 9.9, 21.2],
#    'precip': [0.0, 2.7, 19.1],
#    'humidity': [34.9, 60.3, 93.2],
#    'snowdepth': [11.5, 11.5, 11.5],
#    'windspeed': [0.7, 20.9, 35.3],
#    'windgust': [42.5, 67.7, 81.4],
#    'winddir': [75.7, 214.2, 311.7],
#    'cloudcover': [0.0, 33.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-09',
#   'datetimeEpoch': 1583726400,
#   'tzoffset': -4.0,
#   'tempmax': 21.7,
#   'tempmin': 6.8,
#   'temp': 13.6,
#   'feelslikemax': 15.0,
#   'feelslikemin': -0.5,
#   'feelslike': 6.8,
#   'dew': -2.1,
#   'humidity': 35.43,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 84.0,
#   'windspeed': 22.1,
#   'winddir': 262.7,
#   'pressure': 1026.8,
#   'cloudcover': 0.7,
#   'visibility': 15.8,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:16:30',
#   'sunriseEpoch': 1583752590,
#   'sunset': '18:56:53',
#   'sunsetEpoch': 1583794613,
#   'moonphase': 0.5,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-1.0, 9.6, 24.4],
#    'tempmin': [-10.7, 1.2, 9.3],
#    'feelslike': [-17.4, 9.6, 24.4],
#    'precip': [0.0, 0.8, 9.4],
#    'humidity': [28.4, 54.4, 85.8],
#    'snowdepth': [7.4, 7.4, 7.4],
#    'windspeed': [0.7, 20.5, 33.5],
#    'windgust': [30.6, 54.7, 77.8],
#    'winddir': [52.0, 199.1, 303.6],
#    'cloudcover': [0.0, 33.0, 99.6]},
#   'hours': None},
#  {'datetime': '2020-03-10',
#   'datetimeEpoch': 1583812800,
#   'tzoffset': -4.0,
#   'tempmax': 17.3,
#   'tempmin': 11.2,
#   'temp': 14.6,
#   'feelslikemax': 21.7,
#   'feelslikemin': 4.6,
#   'feelslike': 12.8,
#   'dew': 5.8,
#   'humidity': 56.04,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 83.5,
#   'windspeed': 28.8,
#   'winddir': 267.0,
#   'pressure': 1018.1,
#   'cloudcover': 22.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:14:53',
#   'sunriseEpoch': 1583838893,
#   'sunset': '18:57:59',
#   'sunsetEpoch': 1583881079,
#   'moonphase': 0.51,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-2.1, 9.2, 25.7],
#    'tempmin': [-7.1, 1.5, 17.9],
#    'feelslike': [-12.9, 9.2, 25.7],
#    'precip': [0.0, 2.6, 27.1],
#    'humidity': [34.7, 56.3, 90.8],
#    'snowdepth': [4.0, 4.0, 4.0],
#    'windspeed': [0.4, 19.8, 33.5],
#    'windgust': [25.9, 54.0, 76.0],
#    'winddir': [52.5, 189.4, 311.4],
#    'cloudcover': [0.0, 31.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-11',
#   'datetimeEpoch': 1583899200,
#   'tzoffset': -4.0,
#   'tempmax': 14.3,
#   'tempmin': 7.1,
#   'temp': 10.4,
#   'feelslikemax': 17.3,
#   'feelslikemin': 11.2,
#   'feelslike': 14.6,
#   'dew': -0.1,
#   'humidity': 49.34,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 76.0,
#   'windspeed': 12.4,
#   'winddir': 184.2,
#   'pressure': 1018.9,
#   'cloudcover': 14.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:13:16',
#   'sunriseEpoch': 1583925196,
#   'sunset': '18:59:05',
#   'sunsetEpoch': 1583967545,
#   'moonphase': 0.53,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [0.3, 10.5, 19.4],
#    'tempmin': [-7.1, 2.3, 8.9],
#    'feelslike': [-14.6, 10.5, 19.4],
#    'precip': [0.0, 1.7, 27.5],
#    'humidity': [31.9, 56.9, 85.8],
#    'snowdepth': [3.0, 3.0, 3.0],
#    'windspeed': [0.7, 19.8, 31.7],
#    'windgust': [35.3, 54.0, 78.1],
#    'winddir': [62.3, 223.7, 320.9],
#    'cloudcover': [0.0, 34.1, 99.6]},
#   'hours': None},
#  {'datetime': '2020-03-12',
#   'datetimeEpoch': 1583985600,
#   'tzoffset': -4.0,
#   'tempmax': 8.9,
#   'tempmin': 6.7,
#   'temp': 8.2,
#   'feelslikemax': 14.3,
#   'feelslikemin': 5.7,
#   'feelslike': 10.0,
#   'dew': 2.8,
#   'humidity': 69.87,
#   'precip': 0.04,
#   'precipprob': None,
#   'precipcover': 8.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 55.4,
#   'windspeed': 23.5,
#   'winddir': 67.8,
#   'pressure': 1020.6,
#   'cloudcover': 35.6,
#   'visibility': 15.7,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:11:39',
#   'sunriseEpoch': 1584011499,
#   'sunset': '19:00:10',
#   'sunsetEpoch': 1584054010,
#   'moonphase': 0.56,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [0.9, 9.6, 21.2],
#    'tempmin': [-5.8, 2.4, 10.1],
#    'feelslike': [-11.8, 9.6, 21.2],
#    'precip': [0.0, 2.4, 20.2],
#    'humidity': [24.7, 57.0, 86.6],
#    'snowdepth': [11.5, 11.5, 11.5],
#    'windspeed': [1.1, 20.5, 38.9],
#    'windgust': [47.9, 50.8, 59.4],
#    'winddir': [42.0, 213.8, 310.0],
#    'cloudcover': [0.0, 30.3, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-13',
#   'datetimeEpoch': 1584072000,
#   'tzoffset': -4.0,
#   'tempmax': 20.7,
#   'tempmin': 8.2,
#   'temp': 13.0,
#   'feelslikemax': 8.4,
#   'feelslikemin': 5.0,
#   'feelslike': 6.4,
#   'dew': 5.4,
#   'humidity': 68.06,
#   'precip': 1.12,
#   'precipprob': None,
#   'precipcover': 29.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 52.7,
#   'windspeed': 32.9,
#   'winddir': 196.6,
#   'pressure': 1012.4,
#   'cloudcover': 45.3,
#   'visibility': 13.2,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:10:01',
#   'sunriseEpoch': 1584097801,
#   'sunset': '19:01:15',
#   'sunsetEpoch': 1584140475,
#   'moonphase': 0.6,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [1.8, 8.9, 23.1],
#    'tempmin': [-7.6, 2.2, 12.1],
#    'feelslike': [-10.0, 8.9, 23.1],
#    'precip': [0.0, 7.6, 98.1],
#    'humidity': [33.6, 60.1, 98.7],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.4, 20.2, 48.2],
#    'windgust': [33.5, 61.2, 73.8],
#    'winddir': [57.5, 183.6, 307.8],
#    'cloudcover': [0.0, 35.8, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-14',
#   'datetimeEpoch': 1584158400,
#   'tzoffset': -4.0,
#   'tempmax': 14.9,
#   'tempmin': 6.7,
#   'temp': 10.0,
#   'feelslikemax': 20.7,
#   'feelslikemin': 5.0,
#   'feelslike': 12.3,
#   'dew': -4.5,
#   'humidity': 36.1,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 43.1,
#   'windspeed': 15.2,
#   'winddir': 305.5,
#   'pressure': 1025.8,
#   'cloudcover': 12.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:08:22',
#   'sunriseEpoch': 1584184102,
#   'sunset': '19:02:20',
#   'sunsetEpoch': 1584226940,
#   'moonphase': 0.65,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [1.0, 9.6, 21.1],
#    'tempmin': [-5.9, 2.4, 14.3],
#    'feelslike': [-13.1, 9.6, 21.1],
#    'precip': [0.0, 3.6, 20.5],
#    'humidity': [32.4, 59.7, 89.3],
#    'snowdepth': [173.0, 173.0, 173.0],
#    'windspeed': [0.7, 22.3, 46.4],
#    'windgust': [31.7, 58.7, 76.0],
#    'winddir': [42.3, 183.8, 302.3],
#    'cloudcover': [0.0, 33.7, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-15',
#   'datetimeEpoch': 1584244800,
#   'tzoffset': -4.0,
#   'tempmax': 13.7,
#   'tempmin': 6.6,
#   'temp': 9.0,
#   'feelslikemax': 14.9,
#   'feelslikemin': 3.8,
#   'feelslike': 9.4,
#   'dew': -4.1,
#   'humidity': 40.66,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 31.7,
#   'windspeed': 20.4,
#   'winddir': 131.5,
#   'pressure': 1030.7,
#   'cloudcover': 22.0,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:06:44',
#   'sunriseEpoch': 1584270404,
#   'sunset': '19:03:25',
#   'sunsetEpoch': 1584313405,
#   'moonphase': 0.71,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-1.4, 10.4, 19.8],
#    'tempmin': [-5.7, 3.4, 9.4],
#    'feelslike': [-12.5, 10.4, 19.8],
#    'precip': [0.0, 2.0, 13.4],
#    'humidity': [37.6, 61.7, 81.7],
#    'snowdepth': [20.0, 20.0, 20.0],
#    'windspeed': [1.1, 22.0, 37.1],
#    'windgust': [51.8, 60.8, 82.4],
#    'winddir': [40.4, 195.9, 297.5],
#    'cloudcover': [0.0, 48.1, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-16',
#   'datetimeEpoch': 1584331200,
#   'tzoffset': -4.0,
#   'tempmax': 7.8,
#   'tempmin': 1.7,
#   'temp': 5.1,
#   'feelslikemax': 13.7,
#   'feelslikemin': 3.8,
#   'feelslike': 7.8,
#   'dew': -4.2,
#   'humidity': 52.04,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 52.6,
#   'windspeed': 29.0,
#   'winddir': 69.4,
#   'pressure': 1034.4,
#   'cloudcover': 25.0,
#   'visibility': 15.8,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:05:05',
#   'sunriseEpoch': 1584356705,
#   'sunset': '19:04:29',
#   'sunsetEpoch': 1584399869,
#   'moonphase': 0.76,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [2.2, 10.1, 19.4],
#    'tempmin': [-3.9, 2.3, 9.4],
#    'feelslike': [-10.6, 10.1, 19.4],
#    'precip': [0.0, 4.5, 49.9],
#    'humidity': [32.4, 59.3, 89.7],
#    'snowdepth': [3.0, 11.5, 20.0],
#    'windspeed': [1.1, 20.9, 38.9],
#    'windgust': [30.2, 64.4, 86.0],
#    'winddir': [44.3, 180.1, 292.2],
#    'cloudcover': [0.0, 37.2, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-17',
#   'datetimeEpoch': 1584417600,
#   'tzoffset': -4.0,
#   'tempmax': 11.7,
#   'tempmin': 6.1,
#   'temp': 8.5,
#   'feelslikemax': 5.7,
#   'feelslikemin': -4.2,
#   'feelslike': 1.6,
#   'dew': 4.7,
#   'humidity': 78.0,
#   'precip': 1.71,
#   'precipprob': None,
#   'precipcover': 33.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 59.0,
#   'windspeed': 21.6,
#   'winddir': 192.1,
#   'pressure': 1022.9,
#   'cloudcover': 40.8,
#   'visibility': 15.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:03:26',
#   'sunriseEpoch': 1584443006,
#   'sunset': '19:05:34',
#   'sunsetEpoch': 1584486334,
#   'moonphase': 0.81,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [-0.9, 10.1, 20.7],
#    'tempmin': [-3.9, 1.7, 9.4],
#    'feelslike': [-9.8, 10.1, 20.7],
#    'precip': [0.0, 0.7, 5.4],
#    'humidity': [31.5, 53.7, 91.2],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.1, 18.4, 33.8],
#    'windgust': [38.9, 58.7, 90.7],
#    'winddir': [45.9, 195.1, 304.5],
#    'cloudcover': [0.0, 30.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-18',
#   'datetimeEpoch': 1584504000,
#   'tzoffset': -4.0,
#   'tempmax': 12.1,
#   'tempmin': 6.1,
#   'temp': 8.8,
#   'feelslikemax': 11.7,
#   'feelslikemin': 3.5,
#   'feelslike': 7.4,
#   'dew': -1.2,
#   'humidity': 50.06,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 38.9,
#   'windspeed': 14.4,
#   'winddir': 210.3,
#   'pressure': 1030.7,
#   'cloudcover': 9.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:01:47',
#   'sunriseEpoch': 1584529307,
#   'sunset': '19:06:38',
#   'sunsetEpoch': 1584572798,
#   'moonphase': 0.86,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [2.1, 10.0, 24.2],
#    'tempmin': [-2.8, 3.0, 12.2],
#    'feelslike': [-8.1, 10.0, 24.2],
#    'precip': [0.0, 1.4, 15.5],
#    'humidity': [29.0, 52.0, 93.9],
#    'snowdepth': [13.0, 13.0, 13.0],
#    'windspeed': [1.1, 20.9, 38.9],
#    'windgust': [40.7, 55.8, 64.8],
#    'winddir': [36.3, 197.1, 297.8],
#    'cloudcover': [0.0, 24.3, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-19',
#   'datetimeEpoch': 1584590400,
#   'tzoffset': -4.0,
#   'tempmax': 10.7,
#   'tempmin': 6.1,
#   'temp': 8.4,
#   'feelslikemax': 12.1,
#   'feelslikemin': 3.9,
#   'feelslike': 7.8,
#   'dew': 5.7,
#   'humidity': 83.7,
#   'precip': 22.16,
#   'precipprob': None,
#   'precipcover': 37.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 37.1,
#   'windspeed': 27.1,
#   'winddir': 75.5,
#   'pressure': 1024.5,
#   'cloudcover': 50.1,
#   'visibility': 13.8,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '07:00:08',
#   'sunriseEpoch': 1584615608,
#   'sunset': '19:07:42',
#   'sunsetEpoch': 1584659262,
#   'moonphase': 0.9,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.1, 10.0, 23.0],
#    'tempmin': [-1.7, 2.8, 13.0],
#    'feelslike': [-6.7, 10.0, 23.0],
#    'precip': [0.0, 3.1, 24.3],
#    'humidity': [29.6, 55.8, 89.4],
#    'snowdepth': [5.0, 5.0, 5.0],
#    'windspeed': [0.7, 19.4, 35.3],
#    'windgust': [37.1, 56.2, 79.6],
#    'winddir': [83.6, 177.2, 313.5],
#    'cloudcover': [0.0, 29.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-20',
#   'datetimeEpoch': 1584676800,
#   'tzoffset': -4.0,
#   'tempmax': 22.9,
#   'tempmin': 8.4,
#   'temp': 14.1,
#   'feelslikemax': 10.7,
#   'feelslikemin': 2.5,
#   'feelslike': 6.3,
#   'dew': 9.4,
#   'humidity': 76.34,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 49.7,
#   'windspeed': 23.6,
#   'winddir': 207.9,
#   'pressure': 1014.4,
#   'cloudcover': 45.7,
#   'visibility': 12.7,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:58:29',
#   'sunriseEpoch': 1584701909,
#   'sunset': '19:08:46',
#   'sunsetEpoch': 1584745726,
#   'moonphase': 0.94,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [2.9, 9.7, 23.3],
#    'tempmin': [-2.8, 2.6, 13.3],
#    'feelslike': [-7.0, 9.7, 23.3],
#    'precip': [0.0, 3.6, 25.8],
#    'humidity': [34.2, 56.7, 87.8],
#    'snowdepth': [3.0, 5.2, 7.4],
#    'windspeed': [1.1, 18.7, 31.7],
#    'windgust': [33.5, 54.4, 74.5],
#    'winddir': [45.1, 175.5, 290.0],
#    'cloudcover': [0.0, 41.1, 99.6]},
#   'hours': None},
#  {'datetime': '2020-03-21',
#   'datetimeEpoch': 1584763200,
#   'tzoffset': -4.0,
#   'tempmax': 18.4,
#   'tempmin': 6.6,
#   'temp': 10.1,
#   'feelslikemax': 22.9,
#   'feelslikemin': 6.5,
#   'feelslike': 13.7,
#   'dew': -2.5,
#   'humidity': 42.81,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 50.5,
#   'windspeed': 23.4,
#   'winddir': 162.3,
#   'pressure': 1024.8,
#   'cloudcover': 19.0,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:56:49',
#   'sunriseEpoch': 1584788209,
#   'sunset': '19:09:50',
#   'sunsetEpoch': 1584832190,
#   'moonphase': 0.97,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [4.1, 9.8, 19.2],
#    'tempmin': [-4.1, 2.7, 14.0],
#    'feelslike': [-10.1, 9.8, 19.2],
#    'precip': [0.0, 4.9, 26.3],
#    'humidity': [33.7, 62.9, 94.9],
#    'snowdepth': [8.3, 8.3, 8.3],
#    'windspeed': [1.1, 22.3, 50.0],
#    'windgust': [40.0, 55.4, 79.6],
#    'winddir': [45.5, 181.8, 303.6],
#    'cloudcover': [0.0, 43.0, 99.5]},
#   'hours': None},
#  {'datetime': '2020-03-22',
#   'datetimeEpoch': 1584849600,
#   'tzoffset': -4.0,
#   'tempmax': 8.3,
#   'tempmin': 2.1,
#   'temp': 4.8,
#   'feelslikemax': 18.4,
#   'feelslikemin': 3.3,
#   'feelslike': 8.9,
#   'dew': -6.2,
#   'humidity': 46.11,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 43.4,
#   'windspeed': 27.5,
#   'winddir': 62.4,
#   'pressure': 1037.0,
#   'cloudcover': 35.7,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:55:10',
#   'sunriseEpoch': 1584874510,
#   'sunset': '19:10:53',
#   'sunsetEpoch': 1584918653,
#   'moonphase': 0.99,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [0.1, 10.8, 23.1],
#    'tempmin': [-5.6, 2.7, 13.3],
#    'feelslike': [-12.7, 10.8, 23.1],
#    'precip': [0.0, 4.2, 32.6],
#    'humidity': [22.0, 54.9, 92.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 21.6, 35.3],
#    'windgust': [42.5, 60.5, 81.4],
#    'winddir': [91.0, 254.6, 318.3],
#    'cloudcover': [0.0, 33.4, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-23',
#   'datetimeEpoch': 1584936000,
#   'tzoffset': -4.0,
#   'tempmax': 5.6,
#   'tempmin': 3.8,
#   'temp': 4.2,
#   'feelslikemax': 5.5,
#   'feelslikemin': -3.4,
#   'feelslike': 0.9,
#   'dew': 1.5,
#   'humidity': 83.21,
#   'precip': 17.42,
#   'precipprob': None,
#   'precipcover': 50.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 46.7,
#   'windspeed': 34.2,
#   'winddir': 89.3,
#   'pressure': 1025.9,
#   'cloudcover': 46.2,
#   'visibility': 12.5,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:53:30',
#   'sunriseEpoch': 1584960810,
#   'sunset': '19:11:57',
#   'sunsetEpoch': 1585005117,
#   'moonphase': 1.0,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [3.3, 10.6, 24.0],
#    'tempmin': [-5.1, 2.2, 15.1],
#    'feelslike': [-10.1, 10.6, 24.0],
#    'precip': [0.0, 3.4, 21.8],
#    'humidity': [22.6, 49.1, 91.1],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 20.9, 42.5],
#    'windgust': [40.7, 57.6, 83.5],
#    'winddir': [62.0, 243.2, 317.3],
#    'cloudcover': [0.0, 24.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-24',
#   'datetimeEpoch': 1585022400,
#   'tzoffset': -4.0,
#   'tempmax': 14.2,
#   'tempmin': 3.3,
#   'temp': 8.1,
#   'feelslikemax': 5.6,
#   'feelslikemin': -1.9,
#   'feelslike': 0.3,
#   'dew': 1.6,
#   'humidity': 65.72,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 38.9,
#   'windspeed': 20.1,
#   'winddir': 166.8,
#   'pressure': 1019.7,
#   'cloudcover': 9.8,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:51:51',
#   'sunriseEpoch': 1585047111,
#   'sunset': '19:13:00',
#   'sunsetEpoch': 1585091580,
#   'moonphase': 0.0,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [0.7, 10.9, 18.0],
#    'tempmin': [-5.8, 2.6, 10.1],
#    'feelslike': [-8.6, 10.9, 18.0],
#    'precip': [0.0, 0.4, 2.9],
#    'humidity': [31.4, 47.7, 80.4],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 18.7, 33.5],
#    'windgust': [33.5, 42.1, 53.6],
#    'winddir': [72.6, 185.9, 287.1],
#    'cloudcover': [0.0, 30.5, 93.8]},
#   'hours': None},
#  {'datetime': '2020-03-25',
#   'datetimeEpoch': 1585108800,
#   'tzoffset': -4.0,
#   'tempmax': 7.2,
#   'tempmin': 5.6,
#   'temp': 6.4,
#   'feelslikemax': 14.2,
#   'feelslikemin': 0.1,
#   'feelslike': 6.7,
#   'dew': 1.8,
#   'humidity': 72.46,
#   'precip': 0.02,
#   'precipprob': None,
#   'precipcover': 4.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 49.7,
#   'windspeed': 34.7,
#   'winddir': 39.1,
#   'pressure': 1018.4,
#   'cloudcover': 36.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:50:11',
#   'sunriseEpoch': 1585133411,
#   'sunset': '19:14:04',
#   'sunsetEpoch': 1585178044,
#   'moonphase': 0.01,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [2.2, 9.9, 21.7],
#    'tempmin': [-2.1, 3.5, 9.2],
#    'feelslike': [-7.0, 9.9, 21.7],
#    'precip': [0.0, 0.8, 5.5],
#    'humidity': [35.0, 55.2, 83.2],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 19.8, 37.1],
#    'windgust': [33.5, 56.2, 96.1],
#    'winddir': [46.6, 143.2, 286.0],
#    'cloudcover': [0.0, 34.2, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-26',
#   'datetimeEpoch': 1585195200,
#   'tzoffset': -4.0,
#   'tempmax': 15.5,
#   'tempmin': 4.3,
#   'temp': 8.9,
#   'feelslikemax': 4.0,
#   'feelslikemin': 1.4,
#   'feelslike': 2.8,
#   'dew': 1.8,
#   'humidity': 62.29,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 27.7,
#   'windspeed': 20.0,
#   'winddir': 193.8,
#   'pressure': 1015.4,
#   'cloudcover': 1.6,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:48:32',
#   'sunriseEpoch': 1585219712,
#   'sunset': '19:15:07',
#   'sunsetEpoch': 1585264507,
#   'moonphase': 0.02,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [1.2, 10.1, 18.9],
#    'tempmin': [-3.3, 2.7, 7.2],
#    'feelslike': [-8.9, 10.1, 18.9],
#    'precip': [0.0, 1.6, 8.1],
#    'humidity': [28.6, 59.4, 90.2],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.4, 19.8, 29.5],
#    'windgust': [27.7, 49.3, 63.0],
#    'winddir': [41.5, 161.8, 309.3],
#    'cloudcover': [0.0, 36.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-27',
#   'datetimeEpoch': 1585281600,
#   'tzoffset': -4.0,
#   'tempmax': 21.0,
#   'tempmin': 10.0,
#   'temp': 14.3,
#   'feelslikemax': 15.5,
#   'feelslikemin': 1.0,
#   'feelslike': 7.7,
#   'dew': 3.1,
#   'humidity': 52.18,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 33.5,
#   'windspeed': 16.2,
#   'winddir': 199.3,
#   'pressure': 1011.5,
#   'cloudcover': 19.5,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:46:53',
#   'sunriseEpoch': 1585306013,
#   'sunset': '19:16:10',
#   'sunsetEpoch': 1585350970,
#   'moonphase': 0.04,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [4.7, 11.2, 25.1],
#    'tempmin': [-5.1, 3.0, 10.7],
#    'feelslike': [-9.2, 11.2, 25.1],
#    'precip': [0.0, 1.8, 8.5],
#    'humidity': [19.6, 53.7, 89.4],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 16.9, 35.3],
#    'windgust': [27.7, 39.2, 60.8],
#    'winddir': [70.1, 196.8, 315.5],
#    'cloudcover': [0.0, 26.0, 99.9]},
#   'hours': None},
#  {'datetime': '2020-03-28',
#   'datetimeEpoch': 1585368000,
#   'tzoffset': -4.0,
#   'tempmax': 12.8,
#   'tempmin': 7.8,
#   'temp': 9.3,
#   'feelslikemax': 21.0,
#   'feelslikemin': 10.0,
#   'feelslike': 14.3,
#   'dew': 2.9,
#   'humidity': 67.86,
#   'precip': 0.54,
#   'precipprob': None,
#   'precipcover': 45.83,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 37.1,
#   'windspeed': 25.6,
#   'winddir': 41.6,
#   'pressure': 1018.8,
#   'cloudcover': 34.7,
#   'visibility': 13.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:45:14',
#   'sunriseEpoch': 1585392314,
#   'sunset': '19:17:13',
#   'sunsetEpoch': 1585437433,
#   'moonphase': 0.07,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [4.4, 11.6, 19.2],
#    'tempmin': [-2.8, 3.7, 9.0],
#    'feelslike': [-8.3, 11.6, 19.2],
#    'precip': [0.0, 5.8, 81.0],
#    'humidity': [32.2, 64.2, 100.0],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 20.9, 40.7],
#    'windgust': [35.3, 51.8, 64.8],
#    'winddir': [52.4, 169.3, 292.7],
#    'cloudcover': [0.0, 40.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-29',
#   'datetimeEpoch': 1585454400,
#   'tzoffset': -4.0,
#   'tempmax': 8.3,
#   'tempmin': 7.2,
#   'temp': 7.9,
#   'feelslikemax': 12.8,
#   'feelslikemin': 4.1,
#   'feelslike': 7.2,
#   'dew': 6.8,
#   'humidity': 92.8,
#   'precip': 0.71,
#   'precipprob': None,
#   'precipcover': 25.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 44.7,
#   'windspeed': 34.9,
#   'winddir': 32.7,
#   'pressure': 1013.9,
#   'cloudcover': 52.8,
#   'visibility': 6.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:43:35',
#   'sunriseEpoch': 1585478615,
#   'sunset': '19:18:16',
#   'sunsetEpoch': 1585523896,
#   'moonphase': 0.11,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [7.2, 12.9, 20.1],
#    'tempmin': [-3.8, 5.2, 11.1],
#    'feelslike': [-9.4, 12.9, 20.1],
#    'precip': [0.0, 5.5, 46.2],
#    'humidity': [19.3, 59.8, 96.5],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.4, 21.6, 37.1],
#    'windgust': [29.5, 57.6, 72.0],
#    'winddir': [74.0, 202.5, 319.2],
#    'cloudcover': [0.0, 35.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-30',
#   'datetimeEpoch': 1585540800,
#   'tzoffset': -4.0,
#   'tempmax': 10.0,
#   'tempmin': 6.6,
#   'temp': 8.3,
#   'feelslikemax': 5.5,
#   'feelslikemin': 2.7,
#   'feelslike': 4.4,
#   'dew': 6.0,
#   'humidity': 85.17,
#   'precip': 1.21,
#   'precipprob': None,
#   'precipcover': 4.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': None,
#   'windspeed': 20.0,
#   'winddir': 99.1,
#   'pressure': 1014.2,
#   'cloudcover': 48.5,
#   'visibility': 15.7,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:41:56',
#   'sunriseEpoch': 1585564916,
#   'sunset': '19:19:19',
#   'sunsetEpoch': 1585610359,
#   'moonphase': 0.15,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.7, 13.0, 21.7],
#    'tempmin': [-2.1, 4.8, 10.5],
#    'feelslike': [-7.3, 13.0, 21.7],
#    'precip': [0.0, 6.9, 63.0],
#    'humidity': [19.4, 56.9, 98.6],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.1, 20.5, 42.5],
#    'windgust': [31.7, 52.9, 76.0],
#    'winddir': [36.4, 180.5, 309.5],
#    'cloudcover': [0.0, 35.2, 100.0]},
#   'hours': None},
#  {'datetime': '2020-03-31',
#   'datetimeEpoch': 1585627200,
#   'tzoffset': -4.0,
#   'tempmax': 7.9,
#   'tempmin': 5.6,
#   'temp': 6.6,
#   'feelslikemax': 10.0,
#   'feelslikemin': 3.6,
#   'feelslike': 6.9,
#   'dew': 3.3,
#   'humidity': 79.29,
#   'precip': 1.01,
#   'precipprob': None,
#   'precipcover': 8.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 31.7,
#   'windspeed': 23.7,
#   'winddir': 113.5,
#   'pressure': 1016.1,
#   'cloudcover': 49.3,
#   'visibility': 15.1,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:40:17',
#   'sunriseEpoch': 1585651217,
#   'sunset': '19:20:22',
#   'sunsetEpoch': 1585696822,
#   'moonphase': 0.2,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.7, 12.4, 22.9],
#    'tempmin': [-0.6, 5.0, 10.9],
#    'feelslike': [-6.3, 12.4, 22.9],
#    'precip': [0.0, 5.7, 32.2],
#    'humidity': [28.6, 63.5, 99.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.1, 20.5, 40.0],
#    'windgust': [37.1, 51.1, 59.8],
#    'winddir': [56.3, 175.0, 314.3],
#    'cloudcover': [0.0, 44.8, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-01',
#   'datetimeEpoch': 1585713600,
#   'tzoffset': -4.0,
#   'tempmax': 14.3,
#   'tempmin': 4.3,
#   'temp': 8.8,
#   'feelslikemax': 7.2,
#   'feelslikemin': 1.5,
#   'feelslike': 4.4,
#   'dew': -0.4,
#   'humidity': 54.57,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 36.8,
#   'windspeed': 28.9,
#   'winddir': 115.5,
#   'pressure': 1009.2,
#   'cloudcover': 30.9,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:38:39',
#   'sunriseEpoch': 1585737519,
#   'sunset': '19:21:25',
#   'sunsetEpoch': 1585783285,
#   'moonphase': 0.25,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [6.2, 13.1, 25.7],
#    'tempmin': [-1.1, 6.0, 13.4],
#    'feelslike': [-5.3, 13.1, 25.7],
#    'precip': [0.0, 2.4, 9.8],
#    'humidity': [40.4, 68.7, 98.1],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 19.4, 42.1],
#    'windgust': [37.1, 56.5, 76.0],
#    'winddir': [55.0, 180.1, 283.6],
#    'cloudcover': [0.0, 53.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-02',
#   'datetimeEpoch': 1585800000,
#   'tzoffset': -4.0,
#   'tempmax': 16.0,
#   'tempmin': 4.3,
#   'temp': 10.1,
#   'feelslikemax': 14.3,
#   'feelslikemin': 0.2,
#   'feelslike': 7.1,
#   'dew': -1.4,
#   'humidity': 45.89,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 54.3,
#   'windspeed': 13.2,
#   'winddir': 320.2,
#   'pressure': 1005.6,
#   'cloudcover': 26.7,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:37:01',
#   'sunriseEpoch': 1585823821,
#   'sunset': '19:22:28',
#   'sunsetEpoch': 1585869748,
#   'moonphase': 0.31,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [6.1, 13.3, 19.3],
#    'tempmin': [0.7, 5.2, 9.4],
#    'feelslike': [-3.5, 13.3, 19.3],
#    'precip': [0.0, 2.9, 45.9],
#    'humidity': [31.7, 62.1, 99.1],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 20.5, 35.3],
#    'windgust': [40.7, 54.7, 79.6],
#    'winddir': [57.5, 165.7, 295.5],
#    'cloudcover': [0.0, 37.3, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-03',
#   'datetimeEpoch': 1585886400,
#   'tzoffset': -4.0,
#   'tempmax': 11.6,
#   'tempmin': 7.8,
#   'temp': 10.2,
#   'feelslikemax': 16.0,
#   'feelslikemin': 2.9,
#   'feelslike': 9.5,
#   'dew': 4.5,
#   'humidity': 68.24,
#   'precip': 0.42,
#   'precipprob': None,
#   'precipcover': 37.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 50.0,
#   'windspeed': 25.8,
#   'winddir': 257.7,
#   'pressure': 1005.7,
#   'cloudcover': 34.7,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:35:23',
#   'sunriseEpoch': 1585910123,
#   'sunset': '19:23:31',
#   'sunsetEpoch': 1585956211,
#   'moonphase': 0.36,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.7, 13.6, 23.9],
#    'tempmin': [1.2, 5.8, 14.7],
#    'feelslike': [-4.7, 13.6, 23.9],
#    'precip': [0.0, 2.6, 23.3],
#    'humidity': [25.9, 59.5, 91.0],
#    'snowdepth': [58.0, 58.0, 58.0],
#    'windspeed': [0.4, 19.1, 33.5],
#    'windgust': [40.7, 61.2, 81.4],
#    'winddir': [83.0, 192.4, 294.7],
#    'cloudcover': [0.0, 41.3, 99.6]},
#   'hours': None},
#  {'datetime': '2020-04-04',
#   'datetimeEpoch': 1585972800,
#   'tzoffset': -4.0,
#   'tempmax': 16.1,
#   'tempmin': 8.3,
#   'temp': 10.9,
#   'feelslikemax': 11.6,
#   'feelslikemin': 6.1,
#   'feelslike': 9.9,
#   'dew': 5.8,
#   'humidity': 71.79,
#   'precip': 0.02,
#   'precipprob': None,
#   'precipcover': 8.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 42.5,
#   'windspeed': 18.4,
#   'winddir': 134.4,
#   'pressure': 1015.4,
#   'cloudcover': 41.8,
#   'visibility': 15.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:33:46',
#   'sunriseEpoch': 1585996426,
#   'sunset': '19:24:33',
#   'sunsetEpoch': 1586042673,
#   'moonphase': 0.41,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.9, 12.7, 24.0],
#    'tempmin': [-0.6, 5.2, 9.0],
#    'feelslike': [-4.2, 12.7, 24.0],
#    'precip': [0.0, 5.1, 34.3],
#    'humidity': [24.1, 62.8, 96.5],
#    'snowdepth': [None, None, None],
#    'windspeed': [11.5, 24.1, 40.7],
#    'windgust': [33.5, 57.2, 72.0],
#    'winddir': [46.9, 177.3, 299.0],
#    'cloudcover': [0.0, 49.7, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-05',
#   'datetimeEpoch': 1586059200,
#   'tzoffset': -4.0,
#   'tempmax': 18.3,
#   'tempmin': 7.9,
#   'temp': 11.4,
#   'feelslikemax': 16.1,
#   'feelslikemin': 5.9,
#   'feelslike': 10.0,
#   'dew': 7.2,
#   'humidity': 75.87,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': None,
#   'windspeed': 11.3,
#   'winddir': 134.8,
#   'pressure': 1016.8,
#   'cloudcover': 33.1,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:32:09',
#   'sunriseEpoch': 1586082729,
#   'sunset': '19:25:36',
#   'sunsetEpoch': 1586129136,
#   'moonphase': 0.45,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.7, 12.8, 23.3],
#    'tempmin': [-3.3, 4.3, 14.0],
#    'feelslike': [-10.0, 12.8, 23.3],
#    'precip': [0.0, 0.8, 4.7],
#    'humidity': [32.9, 51.0, 98.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.1, 22.3, 44.6],
#    'windgust': [31.7, 56.5, 79.6],
#    'winddir': [54.4, 215.3, 308.3],
#    'cloudcover': [0.0, 31.1, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-06',
#   'datetimeEpoch': 1586145600,
#   'tzoffset': -4.0,
#   'tempmax': 19.8,
#   'tempmin': 10.0,
#   'temp': 14.0,
#   'feelslikemax': 18.3,
#   'feelslikemin': 6.9,
#   'feelslike': 11.3,
#   'dew': 2.1,
#   'humidity': 50.4,
#   'precip': 0.1,
#   'precipprob': None,
#   'precipcover': 12.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 33.5,
#   'windspeed': 21.8,
#   'winddir': 170.1,
#   'pressure': 1015.9,
#   'cloudcover': 11.6,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:30:33',
#   'sunriseEpoch': 1586169033,
#   'sunset': '19:26:39',
#   'sunsetEpoch': 1586215599,
#   'moonphase': 0.48,
#   'conditions': 'Rain',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [5.1, 13.2, 25.1],
#    'tempmin': [-1.1, 4.5, 15.9],
#    'feelslike': [-5.4, 13.2, 25.1],
#    'precip': [0.0, 1.9, 14.3],
#    'humidity': [24.7, 54.9, 88.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 21.2, 44.6],
#    'windgust': [25.9, 47.5, 68.4],
#    'winddir': [57.5, 194.8, 299.0],
#    'cloudcover': [0.0, 27.5, 90.4]},
#   'hours': None},
#  {'datetime': '2020-04-07',
#   'datetimeEpoch': 1586232000,
#   'tzoffset': -4.0,
#   'tempmax': 18.9,
#   'tempmin': 10.1,
#   'temp': 14.0,
#   'feelslikemax': 19.8,
#   'feelslikemin': 8.5,
#   'feelslike': 13.8,
#   'dew': 0.6,
#   'humidity': 41.77,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 42.5,
#   'windspeed': 21.9,
#   'winddir': 183.3,
#   'pressure': 1011.9,
#   'cloudcover': 19.9,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:28:56',
#   'sunriseEpoch': 1586255336,
#   'sunset': '19:27:42',
#   'sunsetEpoch': 1586302062,
#   'moonphase': 0.5,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [3.4, 14.0, 32.2],
#    'tempmin': [-1.1, 5.9, 13.3],
#    'feelslike': [-7.9, 14.0, 30.1],
#    'precip': [0.0, 1.5, 13.2],
#    'humidity': [27.9, 58.2, 82.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [9.7, 20.9, 33.5],
#    'windgust': [35.3, 58.0, 80.6],
#    'winddir': [46.2, 181.8, 323.3],
#    'cloudcover': [0.0, 41.3, 99.6]},
#   'hours': None},
#  {'datetime': '2020-04-08',
#   'datetimeEpoch': 1586318400,
#   'tzoffset': -4.0,
#   'tempmax': 19.2,
#   'tempmin': 9.4,
#   'temp': 13.9,
#   'feelslikemax': 18.9,
#   'feelslikemin': 10.1,
#   'feelslike': 14.0,
#   'dew': 8.7,
#   'humidity': 72.38,
#   'precip': 2.42,
#   'precipprob': None,
#   'precipcover': 12.5,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': None,
#   'windspeed': 14.0,
#   'winddir': 123.9,
#   'pressure': 1001.7,
#   'cloudcover': 27.4,
#   'visibility': 15.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:27:21',
#   'sunriseEpoch': 1586341641,
#   'sunset': '19:28:45',
#   'sunsetEpoch': 1586388525,
#   'moonphase': 0.5,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [2.9, 13.9, 26.7],
#    'tempmin': [-1.0, 6.1, 18.0],
#    'feelslike': [-6.6, 13.9, 26.7],
#    'precip': [0.0, 3.1, 15.7],
#    'humidity': [26.0, 61.0, 95.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 19.4, 31.7],
#    'windgust': [40.7, 55.4, 82.8],
#    'winddir': [49.5, 186.7, 289.3],
#    'cloudcover': [0.0, 44.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-04-09',
#   'datetimeEpoch': 1586404800,
#   'tzoffset': -4.0,
#   'tempmax': 14.3,
#   'tempmin': 8.3,
#   'temp': 10.8,
#   'feelslikemax': 19.2,
#   'feelslikemin': 8.8,
#   'feelslike': 13.9,
#   'dew': 5.0,
#   'humidity': 70.02,
#   'precip': 1.17,
#   'precipprob': None,
#   'precipcover': 16.67,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 68.1,
#   'windspeed': 16.6,
#   'winddir': 231.5,
#   'pressure': 995.6,
#   'cloudcover': 25.5,
#   'visibility': 15.6,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '06:25:46',
#   'sunriseEpoch': 1586427946,
#   'sunset': '19:29:48',
#   'sunsetEpoch': 1586474988,
#   'moonphase': 0.52,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [3.9, 14.9, 27.6],
#    'tempmin': [0.3, 5.9, 11.2],
#    'feelslike': [-3.4, 14.9, 26.4],
#    'precip': [0.0, 2.6, 15.0],
#    'humidity': [27.4, 58.6, 96.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [1.1, 19.4, 33.5],
#    'windgust': [27.7, 46.8, 79.6],
# ...
#    'humidity': [41.0, 66.6, 96.6],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 18.0, 33.5],
#    'windgust': [29.5, 55.8, 81.4],
#    'winddir': [45.7, 132.1, 259.3],
#    'cloudcover': [0.0, 41.7, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-19',
#   'datetimeEpoch': 1589860800,
#   'tzoffset': -4.0,
#   'tempmax': 19.4,
#   'tempmin': 12.8,
#   'temp': 15.6,
#   'feelslikemax': 20.6,
#   'feelslikemin': 13.3,
#   'feelslike': 16.3,
#   'dew': 4.2,
#   'humidity': 48.18,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 48.3,
#   'windspeed': 33.5,
#   'winddir': 50.2,
#   'pressure': 1024.2,
#   'cloudcover': 1.0,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:35:00',
#   'sunriseEpoch': 1589880900,
#   'sunset': '20:10:39',
#   'sunsetEpoch': 1589933439,
#   'moonphase': 0.96,
#   'conditions': 'Clear',
#   'icon': 'wind',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [13.9, 20.6, 32.1],
#    'tempmin': [5.1, 12.5, 21.1],
#    'feelslike': [3.6, 20.6, 32.2],
#    'precip': [0.0, 5.1, 33.9],
#    'humidity': [36.1, 66.9, 98.5],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 14.4, 25.6],
#    'windgust': [35.3, 52.9, 63.0],
#    'winddir': [48.0, 175.1, 296.7],
#    'cloudcover': [0.0, 36.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-20',
#   'datetimeEpoch': 1589947200,
#   'tzoffset': -4.0,
#   'tempmax': 18.8,
#   'tempmin': 10.6,
#   'temp': 14.0,
#   'feelslikemax': 19.4,
#   'feelslikemin': 12.8,
#   'feelslike': 15.6,
#   'dew': 3.0,
#   'humidity': 48.49,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 38.9,
#   'windspeed': 27.7,
#   'winddir': 71.4,
#   'pressure': 1030.3,
#   'cloudcover': 1.2,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:34:12',
#   'sunriseEpoch': 1589967252,
#   'sunset': '20:11:34',
#   'sunsetEpoch': 1590019894,
#   'moonphase': 0.98,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [12.9, 21.9, 28.3],
#    'tempmin': [6.7, 12.7, 19.9],
#    'feelslike': [4.2, 21.9, 28.7],
#    'precip': [0.0, 1.3, 11.5],
#    'humidity': [35.3, 60.3, 91.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 16.9, 31.7],
#    'windgust': [46.4, 74.5, 94.3],
#    'winddir': [60.0, 198.5, 301.2],
#    'cloudcover': [0.0, 27.3, 77.0]},
#   'hours': None},
#  {'datetime': '2020-05-21',
#   'datetimeEpoch': 1590033600,
#   'tzoffset': -4.0,
#   'tempmax': 19.3,
#   'tempmin': 9.9,
#   'temp': 14.2,
#   'feelslikemax': 18.8,
#   'feelslikemin': 10.6,
#   'feelslike': 14.1,
#   'dew': 7.6,
#   'humidity': 65.74,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 25.9,
#   'windspeed': 14.8,
#   'winddir': 109.4,
#   'pressure': 1028.7,
#   'cloudcover': 3.5,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:33:25',
#   'sunriseEpoch': 1590053605,
#   'sunset': '20:12:28',
#   'sunsetEpoch': 1590106348,
#   'moonphase': 1.0,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [13.9, 21.5, 29.0],
#    'tempmin': [6.2, 13.0, 18.3],
#    'feelslike': [4.7, 21.5, 29.3],
#    'precip': [0.0, 3.2, 35.8],
#    'humidity': [34.5, 61.9, 93.8],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 15.8, 24.1],
#    'windgust': [31.7, 68.8, 104.0],
#    'winddir': [65.5, 182.4, 297.1],
#    'cloudcover': [0.0, 34.7, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-22',
#   'datetimeEpoch': 1590120000,
#   'tzoffset': -4.0,
#   'tempmax': 24.3,
#   'tempmin': 13.3,
#   'temp': 17.8,
#   'feelslikemax': 19.3,
#   'feelslikemin': 8.2,
#   'feelslike': 14.0,
#   'dew': 13.4,
#   'humidity': 76.94,
#   'precip': 0.04,
#   'precipprob': None,
#   'precipcover': 8.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 35.3,
#   'windspeed': 14.9,
#   'winddir': 133.9,
#   'pressure': 1021.1,
#   'cloudcover': 26.7,
#   'visibility': 15.1,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:32:41',
#   'sunriseEpoch': 1590139961,
#   'sunset': '20:13:22',
#   'sunsetEpoch': 1590192802,
#   'moonphase': 1.0,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [13.4, 20.3, 29.0],
#    'tempmin': [7.9, 13.1, 17.9],
#    'feelslike': [6.0, 20.3, 30.1],
#    'precip': [0.0, 3.3, 25.0],
#    'humidity': [41.3, 70.8, 97.3],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 15.5, 27.7],
#    'windgust': [33.5, 69.5, 116.6],
#    'winddir': [50.9, 148.4, 288.9],
#    'cloudcover': [0.0, 39.8, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-23',
#   'datetimeEpoch': 1590206400,
#   'tzoffset': -4.0,
#   'tempmax': 19.3,
#   'tempmin': 13.8,
#   'temp': 16.3,
#   'feelslikemax': 24.3,
#   'feelslikemin': 13.3,
#   'feelslike': 17.8,
#   'dew': 14.1,
#   'humidity': 87.27,
#   'precip': 8.0,
#   'precipprob': None,
#   'precipcover': 25.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 50.1,
#   'windspeed': 35.3,
#   'winddir': 54.5,
#   'pressure': 1016.8,
#   'cloudcover': 49.4,
#   'visibility': 11.7,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:31:58',
#   'sunriseEpoch': 1590226318,
#   'sunset': '20:14:14',
#   'sunsetEpoch': 1590279254,
#   'moonphase': 0.0,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [13.4, 21.3, 30.7],
#    'tempmin': [7.2, 13.0, 18.2],
#    'feelslike': [5.5, 21.3, 33.9],
#    'precip': [0.0, 5.3, 45.6],
#    'humidity': [34.4, 72.0, 97.5],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 16.9, 28.4],
#    'windgust': [40.0, 83.5, 126.0],
#    'winddir': [51.1, 158.6, 295.7],
#    'cloudcover': [0.0, 33.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-24',
#   'datetimeEpoch': 1590292800,
#   'tzoffset': -4.0,
#   'tempmax': 21.1,
#   'tempmin': 12.1,
#   'temp': 15.6,
#   'feelslikemax': 19.3,
#   'feelslikemin': 13.8,
#   'feelslike': 16.3,
#   'dew': 9.3,
#   'humidity': 66.51,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 42.5,
#   'windspeed': 29.6,
#   'winddir': 73.8,
#   'pressure': 1024.0,
#   'cloudcover': 39.0,
#   'visibility': 15.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:31:17',
#   'sunriseEpoch': 1590312677,
#   'sunset': '20:15:06',
#   'sunsetEpoch': 1590365706,
#   'moonphase': 0.02,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [13.4, 22.4, 29.0],
#    'tempmin': [8.6, 14.0, 18.9],
#    'feelslike': [5.6, 22.4, 28.9],
#    'precip': [0.0, 5.4, 49.1],
#    'humidity': [39.8, 70.8, 97.9],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 17.3, 31.7],
#    'windgust': [29.5, 69.8, 107.3],
#    'winddir': [57.9, 168.8, 283.8],
#    'cloudcover': [0.0, 41.9, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-25',
#   'datetimeEpoch': 1590379200,
#   'tzoffset': -4.0,
#   'tempmax': 22.7,
#   'tempmin': 13.4,
#   'temp': 17.0,
#   'feelslikemax': 21.1,
#   'feelslikemin': 12.1,
#   'feelslike': 15.6,
#   'dew': 13.0,
#   'humidity': 78.22,
#   'precip': 0.14,
#   'precipprob': None,
#   'precipcover': 4.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': None,
#   'windspeed': 18.5,
#   'winddir': 96.9,
#   'pressure': 1023.3,
#   'cloudcover': 35.8,
#   'visibility': 15.4,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:30:37',
#   'sunriseEpoch': 1590399037,
#   'sunset': '20:15:57',
#   'sunsetEpoch': 1590452157,
#   'moonphase': 0.04,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [11.9, 22.8, 31.9],
#    'tempmin': [7.9, 14.2, 18.2],
#    'feelslike': [6.3, 22.8, 30.3],
#    'precip': [0.0, 1.1, 6.8],
#    'humidity': [39.7, 65.0, 93.0],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 18.4, 37.1],
#    'windgust': [31.7, 54.0, 86.8],
#    'winddir': [56.6, 186.3, 307.1],
#    'cloudcover': [0.0, 25.6, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-26',
#   'datetimeEpoch': 1590465600,
#   'tzoffset': -4.0,
#   'tempmax': 23.9,
#   'tempmin': 14.4,
#   'temp': 18.1,
#   'feelslikemax': 22.7,
#   'feelslikemin': 13.4,
#   'feelslike': 17.0,
#   'dew': 14.8,
#   'humidity': 82.04,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 85.0,
#   'windspeed': 14.9,
#   'winddir': 178.1,
#   'pressure': 1023.2,
#   'cloudcover': 25.3,
#   'visibility': 11.8,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:30:00',
#   'sunriseEpoch': 1590485400,
#   'sunset': '20:16:47',
#   'sunsetEpoch': 1590538607,
#   'moonphase': 0.07,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [12.9, 24.0, 33.0],
#    'tempmin': [9.7, 15.8, 22.2],
#    'feelslike': [9.7, 24.0, 34.0],
#    'precip': [0.0, 2.9, 38.5],
#    'humidity': [36.3, 67.3, 96.3],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 17.3, 38.9],
#    'windgust': [33.5, 54.4, 83.2],
#    'winddir': [52.5, 183.9, 301.8],
#    'cloudcover': [0.0, 33.0, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-27',
#   'datetimeEpoch': 1590552000,
#   'tzoffset': -4.0,
#   'tempmax': 24.3,
#   'tempmin': 15.0,
#   'temp': 18.6,
#   'feelslikemax': 23.9,
#   'feelslikemin': 14.4,
#   'feelslike': 18.1,
#   'dew': 15.4,
#   'humidity': 82.35,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': None,
#   'windspeed': 16.7,
#   'winddir': 137.6,
#   'pressure': 1023.7,
#   'cloudcover': 31.4,
#   'visibility': 13.8,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:29:25',
#   'sunriseEpoch': 1590571765,
#   'sunset': '20:17:36',
#   'sunsetEpoch': 1590625056,
#   'moonphase': 0.11,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [18.2, 25.3, 30.1],
#    'tempmin': [10.7, 16.1, 23.4],
#    'feelslike': [10.7, 25.3, 30.9],
#    'precip': [0.0, 2.8, 18.4],
#    'humidity': [38.0, 69.0, 91.7],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 16.2, 36.4],
#    'windgust': [46.4, 67.0, 100.1],
#    'winddir': [60.0, 160.2, 286.3],
#    'cloudcover': [0.0, 35.6, 90.4]},
#   'hours': None},
#  {'datetime': '2020-05-28',
#   'datetimeEpoch': 1590638400,
#   'tzoffset': -4.0,
#   'tempmax': 23.9,
#   'tempmin': 16.8,
#   'temp': 20.1,
#   'feelslikemax': 24.3,
#   'feelslikemin': 15.0,
#   'feelslike': 18.6,
#   'dew': 17.8,
#   'humidity': 86.89,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 49.5,
#   'windspeed': 20.6,
#   'winddir': 127.5,
#   'pressure': 1021.3,
#   'cloudcover': 44.2,
#   'visibility': 14.7,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:28:51',
#   'sunriseEpoch': 1590658131,
#   'sunset': '20:18:24',
#   'sunsetEpoch': 1590711504,
#   'moonphase': 0.16,
#   'conditions': 'Partially cloudy',
#   'icon': 'partly-cloudy-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [16.2, 24.0, 32.2],
#    'tempmin': [11.7, 16.3, 21.7],
#    'feelslike': [11.7, 24.0, 33.6],
#    'precip': [0.0, 2.1, 13.4],
#    'humidity': [38.1, 69.9, 93.4],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 14.8, 22.3],
#    'windgust': [37.1, 63.7, 81.7],
#    'winddir': [60.0, 170.8, 310.0],
#    'cloudcover': [0.0, 31.5, 100.0]},
#   'hours': None},
#  {'datetime': '2020-05-29',
#   'datetimeEpoch': 1590724800,
#   'tzoffset': -4.0,
#   'tempmax': 27.2,
#   'tempmin': 18.9,
#   'temp': 22.9,
#   'feelslikemax': 23.9,
#   'feelslikemin': 16.8,
#   'feelslike': 20.1,
#   'dew': 19.2,
#   'humidity': 80.54,
#   'precip': 0.25,
#   'precipprob': None,
#   'precipcover': 8.33,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 42.5,
#   'windspeed': 18.4,
#   'winddir': 142.2,
#   'pressure': 1015.3,
#   'cloudcover': 38.1,
#   'visibility': 15.5,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:28:19',
#   'sunriseEpoch': 1590744499,
#   'sunset': '20:19:11',
#   'sunsetEpoch': 1590797951,
#   'moonphase': 0.21,
#   'conditions': 'Rain, Partially cloudy',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [15.3, 25.1, 31.2],
#    'tempmin': [10.7, 15.9, 21.7],
#    'feelslike': [10.7, 25.1, 33.5],
#    'precip': [0.0, 2.1, 16.2],
#    'humidity': [33.4, 66.6, 87.7],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 14.0, 24.1],
#    'windgust': [29.5, 42.1, 64.8],
#    'winddir': [40.0, 182.7, 309.2],
#    'cloudcover': [0.0, 22.0, 86.8]},
#   'hours': None},
#  {'datetime': '2020-05-30',
#   'datetimeEpoch': 1590811200,
#   'tzoffset': -4.0,
#   'tempmax': 28.3,
#   'tempmin': 19.4,
#   'temp': 23.5,
#   'feelslikemax': 28.5,
#   'feelslikemin': 18.9,
#   'feelslike': 23.1,
#   'dew': 13.8,
#   'humidity': 58.76,
#   'precip': 0.02,
#   'precipprob': None,
#   'precipcover': 4.17,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 50.0,
#   'windspeed': 18.4,
#   'winddir': 254.7,
#   'pressure': 1012.0,
#   'cloudcover': 18.2,
#   'visibility': 15.9,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:27:50',
#   'sunriseEpoch': 1590830870,
#   'sunset': '20:19:57',
#   'sunsetEpoch': 1590884397,
#   'moonphase': 0.27,
#   'conditions': 'Rain',
#   'icon': 'rain',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [15.1, 25.3, 31.9],
#    'tempmin': [10.7, 16.7, 22.1],
#    'feelslike': [10.7, 25.3, 32.0],
#    'precip': [0.0, 3.9, 41.9],
#    'humidity': [37.0, 64.2, 91.6],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.4, 14.0, 24.1],
#    'windgust': [35.3, 53.3, 72.0],
#    'winddir': [70.7, 190.0, 300.0],
#    'cloudcover': [0.0, 20.5, 73.8]},
#   'hours': None},
#  {'datetime': '2020-05-31',
#   'datetimeEpoch': 1590897600,
#   'tzoffset': -4.0,
#   'tempmax': 22.7,
#   'tempmin': 14.3,
#   'temp': 18.4,
#   'feelslikemax': 22.7,
#   'feelslikemin': 14.3,
#   'feelslike': 18.6,
#   'dew': 4.1,
#   'humidity': 39.84,
#   'precip': 0.0,
#   'precipprob': None,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 53.1,
#   'windspeed': 16.5,
#   'winddir': 327.0,
#   'pressure': 1018.0,
#   'cloudcover': 7.7,
#   'visibility': 16.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'sunrise': '05:27:22',
#   'sunriseEpoch': 1590917242,
#   'sunset': '20:20:41',
#   'sunsetEpoch': 1590970841,
#   'moonphase': 0.33,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['72505394728',
#    '72055399999',
#    'KLGA',
#    'KJRB',
#    'KNYC',
#    '72503014732'],
#   'source': 'obs',
#   'normal': {'tempmax': [17.9, 26.0, 33.0],
#    'tempmin': [10.7, 17.5, 23.1],
#    'feelslike': [10.7, 26.0, 32.5],
#    'precip': [0.0, 4.0, 37.3],
#    'humidity': [38.6, 65.7, 89.2],
#    'snowdepth': [None, None, None],
#    'windspeed': [0.7, 15.8, 27.7],
#    'windgust': [27.7, 49.3, 83.2],
#    'winddir': [60.1, 171.0, 296.4],
#    'cloudcover': [0.0, 20.2, 66.3]},
#   'hours': None}]

# %% [markdown]
# Check if we actually got the data for all the days

# %%
weather['days'][0]

# %%
weather['days'][-1]
# Out:
# {'datetime': '2020-05-31',
#  'datetimeEpoch': 1590897600,
#  'tzoffset': -4.0,
#  'tempmax': 22.7,
#  'tempmin': 14.3,
#  'temp': 18.4,
#  'feelslikemax': 22.7,
#  'feelslikemin': 14.3,
#  'feelslike': 18.6,
#  'dew': 4.1,
#  'humidity': 39.84,
#  'precip': 0.0,
#  'precipprob': None,
#  'precipcover': 0.0,
#  'preciptype': None,
#  'snow': 0.0,
#  'snowdepth': 0.0,
#  'windgust': 53.1,
#  'windspeed': 16.5,
#  'winddir': 327.0,
#  'pressure': 1018.0,
#  'cloudcover': 7.7,
#  'visibility': 16.0,
#  'solarradiation': None,
#  'solarenergy': None,
#  'sunrise': '05:27:22',
#  'sunriseEpoch': 1590917242,
#  'sunset': '20:20:41',
#  'sunsetEpoch': 1590970841,
#  'moonphase': 0.33,
#  'conditions': 'Clear',
#  'icon': 'clear-day',
#  'stations': ['72505394728',
#   '72055399999',
#   'KLGA',
#   'KJRB',
#   'KNYC',
#   '72503014732'],
#  'source': 'obs',
#  'normal': {'tempmax': [17.9, 26.0, 33.0],
#   'tempmin': [10.7, 17.5, 23.1],
#   'feelslike': [10.7, 26.0, 32.5],
#   'precip': [0.0, 4.0, 37.3],
#   'humidity': [38.6, 65.7, 89.2],
#   'snowdepth': [None, None, None],
#   'windspeed': [0.7, 15.8, 27.7],
#   'windgust': [27.7, 49.3, 83.2],
#   'winddir': [60.1, 171.0, 296.4],
#   'cloudcover': [0.0, 20.2, 66.3]},
#  'hours': None}

# %% [raw]
# Hoe many day we have

# %%
len(weather['days'])
# Out:
# 92

# %% [markdown]
# Transform data to a dataframe

# %%
weather_df = pd.DataFrame(weather['days'])
weather_df
# Out:
#       datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0   2020-03-01     1583038800      8.7     -2.9   2.4           8.0
# 1   2020-03-02     1583125200     14.3      3.9   9.1          14.3
# 2   2020-03-03     1583211600     14.8      8.9  11.1          14.8
# 3   2020-03-04     1583298000     13.8      7.2  10.2          13.8
# 4   2020-03-05     1583384400     12.1      4.3   7.6          12.1
# ..         ...            ...      ...      ...   ...           ...
# 87  2020-05-27     1590552000     24.3     15.0  18.6          23.9
# 88  2020-05-28     1590638400     23.9     16.8  20.1          24.3
# 89  2020-05-29     1590724800     27.2     18.9  22.9          23.9
# 90  2020-05-30     1590811200     28.3     19.4  23.5          28.5
# 91  2020-05-31     1590897600     22.7     14.3  18.4          22.7
#
#     feelslikemin  feelslike   dew  humidity  ...    sunset sunsetEpoch  \
# 0           -7.4       -0.4  -8.4     46.32  ...  17:47:57  1583102877
# 1            1.8        8.4   0.0     53.31  ...  17:49:05  1583189345
# 2            7.8       10.8   7.1     77.41  ...  17:50:13  1583275813
# 3            3.2        8.9  -0.2     50.65  ...  17:51:20  1583362280
# 4            2.3        6.5  -2.1     51.97  ...  17:52:27  1583448747
# ..           ...        ...   ...       ...  ...       ...         ...
# 87          14.4       18.1  15.4     82.35  ...  20:17:36  1590625056
# 88          15.0       18.6  17.8     86.89  ...  20:18:24  1590711504
# 89          16.8       20.1  19.2     80.54  ...  20:19:11  1590797951
# 90          18.9       23.1  13.8     58.76  ...  20:19:57  1590884397
# 91          14.3       18.6   4.1     39.84  ...  20:20:41  1590970841
#
#     moonphase              conditions               icon  \
# 0        0.18                   Clear          clear-day
# 1        0.23                    Rain               rain
# 2        0.28                    Rain               rain
# 3        0.34                    Rain               rain
# 4        0.38                   Clear          clear-day
# ..        ...                     ...                ...
# 87       0.11        Partially cloudy  partly-cloudy-day
# 88       0.16        Partially cloudy  partly-cloudy-day
# 89       0.21  Rain, Partially cloudy               rain
# 90       0.27                    Rain               rain
# 91       0.33                   Clear          clear-day
#
#                                              stations  source  \
# 0   [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 1   [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 2   [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 3   [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 4   [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# ..                                                ...     ...
# 87  [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 88  [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 89  [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 90  [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
# 91  [72505394728, 72055399999, KLGA, KJRB, KNYC, 7...     obs
#
#                                                normal  hours  tzoffset
# 0   {'tempmax': [-1.1, 7.4, 19.6], 'tempmin': [-8....   None       NaN
# 1   {'tempmax': [-2.8, 7.5, 19.4], 'tempmin': [-8....   None       NaN
# 2   {'tempmax': [-3.1, 6.4, 16.2], 'tempmin': [-11...   None       NaN
# 3   {'tempmax': [-2.1, 5.5, 17.2], 'tempmin': [-10...   None       NaN
# 4   {'tempmax': [0.1, 6.3, 15.1], 'tempmin': [-8.6...   None       NaN
# ..                                                ...    ...       ...
# 87  {'tempmax': [18.2, 25.3, 30.1], 'tempmin': [10...   None      -4.0
# 88  {'tempmax': [16.2, 24.0, 32.2], 'tempmin': [11...   None      -4.0
# 89  {'tempmax': [15.3, 25.1, 31.2], 'tempmin': [10...   None      -4.0
# 90  {'tempmax': [15.1, 25.3, 31.9], 'tempmin': [10...   None      -4.0
# 91  {'tempmax': [17.9, 26.0, 33.0], 'tempmin': [10...   None      -4.0
#
# [92 rows x 36 columns]

# %%
weather_df.drop(['datetimeEpoch', 'solarradiation', 'solarenergy','sunriseEpoch','sunsetEpoch' ,'stations','source', 'normal', 'hours', 'tzoffset', 'icon'], axis='columns', inplace=True)
weather_df
# Out:
#       datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  \
# 0   2020-03-01      8.7     -2.9   2.4           8.0          -7.4       -0.4
# 1   2020-03-02     14.3      3.9   9.1          14.3           1.8        8.4
# 2   2020-03-03     14.8      8.9  11.1          14.8           7.8       10.8
# 3   2020-03-04     13.8      7.2  10.2          13.8           3.2        8.9
# 4   2020-03-05     12.1      4.3   7.6          12.1           2.3        6.5
# ..         ...      ...      ...   ...           ...           ...        ...
# 87  2020-05-27     24.3     15.0  18.6          23.9          14.4       18.1
# 88  2020-05-28     23.9     16.8  20.1          24.3          15.0       18.6
# 89  2020-05-29     27.2     18.9  22.9          23.9          16.8       20.1
# 90  2020-05-30     28.3     19.4  23.5          28.5          18.9       23.1
# 91  2020-05-31     22.7     14.3  18.4          22.7          14.3       18.6
#
#      dew  humidity  precip  ... windgust  windspeed winddir  pressure  \
# 0   -8.4     46.32    0.00  ...     64.8       22.0   280.6    1020.4
# 1    0.0     53.31    0.24  ...     61.3       23.4   239.9    1014.9
# 2    7.1     77.41    7.93  ...     85.0       14.7   213.8    1004.4
# 3   -0.2     50.65    0.97  ...     79.8       39.6   270.9    1007.2
# 4   -2.1     51.97    0.00  ...     73.8       14.1   254.4    1018.8
# ..   ...       ...     ...  ...      ...        ...     ...       ...
# 87  15.4     82.35    0.00  ...      NaN       16.7   137.6    1023.7
# 88  17.8     86.89    0.00  ...     49.5       20.6   127.5    1021.3
# 89  19.2     80.54    0.25  ...     42.5       18.4   142.2    1015.3
# 90  13.8     58.76    0.02  ...     50.0       18.4   254.7    1012.0
# 91   4.1     39.84    0.00  ...     53.1       16.5   327.0    1018.0
#
#     cloudcover  visibility   sunrise    sunset  moonphase  \
# 0          4.6        16.0  06:29:07  17:47:57       0.18
# 1         14.5        16.0  06:27:35  17:49:05       0.23
# 2         23.4        14.3  06:26:01  17:50:13       0.28
# 3          7.1        16.0  06:24:28  17:51:20       0.34
# 4          1.9        16.0  06:22:53  17:52:27       0.38
# ..         ...         ...       ...       ...        ...
# 87        31.4        13.8  05:29:25  20:17:36       0.11
# 88        44.2        14.7  05:28:51  20:18:24       0.16
# 89        38.1        15.5  05:28:19  20:19:11       0.21
# 90        18.2        15.9  05:27:50  20:19:57       0.27
# 91         7.7        16.0  05:27:22  20:20:41       0.33
#
#                 conditions
# 0                    Clear
# 1                     Rain
# 2                     Rain
# 3                     Rain
# 4                    Clear
# ..                     ...
# 87        Partially cloudy
# 88        Partially cloudy
# 89  Rain, Partially cloudy
# 90                    Rain
# 91                   Clear
#
# [92 rows x 25 columns]

# %%
weather_df.dtypes
# Out:
# datetime         object
# tempmax         float64
# tempmin         float64
# temp            float64
# feelslikemax    float64
# feelslikemin    float64
# feelslike       float64
# dew             float64
# humidity        float64
# precip          float64
# precipprob       object
# precipcover     float64
# preciptype       object
# snow            float64
# snowdepth       float64
# windgust        float64
# windspeed       float64
# winddir         float64
# pressure        float64
# cloudcover      float64
# visibility      float64
# sunrise          object
# sunset           object
# moonphase       float64
# conditions       object
# dtype: object

# %%
weather_df.drop(['precipprob', 'preciptype', 'precipcover', 'windgust', 'winddir'], axis='columns', inplace=True)
weather_df
# Out:
#       datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  \
# 0   2020-03-01      8.7     -2.9   2.4           8.0          -7.4       -0.4
# 1   2020-03-02     14.3      3.9   9.1          14.3           1.8        8.4
# 2   2020-03-03     14.8      8.9  11.1          14.8           7.8       10.8
# 3   2020-03-04     13.8      7.2  10.2          13.8           3.2        8.9
# 4   2020-03-05     12.1      4.3   7.6          12.1           2.3        6.5
# ..         ...      ...      ...   ...           ...           ...        ...
# 87  2020-05-27     24.3     15.0  18.6          23.9          14.4       18.1
# 88  2020-05-28     23.9     16.8  20.1          24.3          15.0       18.6
# 89  2020-05-29     27.2     18.9  22.9          23.9          16.8       20.1
# 90  2020-05-30     28.3     19.4  23.5          28.5          18.9       23.1
# 91  2020-05-31     22.7     14.3  18.4          22.7          14.3       18.6
#
#      dew  humidity  precip  snow  snowdepth  windspeed  pressure  cloudcover  \
# 0   -8.4     46.32    0.00   0.0        0.0       22.0    1020.4         4.6
# 1    0.0     53.31    0.24   0.0        0.0       23.4    1014.9        14.5
# 2    7.1     77.41    7.93   0.0        0.0       14.7    1004.4        23.4
# 3   -0.2     50.65    0.97   0.0        0.0       39.6    1007.2         7.1
# 4   -2.1     51.97    0.00   0.0        0.0       14.1    1018.8         1.9
# ..   ...       ...     ...   ...        ...        ...       ...         ...
# 87  15.4     82.35    0.00   0.0        0.0       16.7    1023.7        31.4
# 88  17.8     86.89    0.00   0.0        0.0       20.6    1021.3        44.2
# 89  19.2     80.54    0.25   0.0        0.0       18.4    1015.3        38.1
# 90  13.8     58.76    0.02   0.0        0.0       18.4    1012.0        18.2
# 91   4.1     39.84    0.00   0.0        0.0       16.5    1018.0         7.7
#
#     visibility   sunrise    sunset  moonphase              conditions
# 0         16.0  06:29:07  17:47:57       0.18                   Clear
# 1         16.0  06:27:35  17:49:05       0.23                    Rain
# 2         14.3  06:26:01  17:50:13       0.28                    Rain
# 3         16.0  06:24:28  17:51:20       0.34                    Rain
# 4         16.0  06:22:53  17:52:27       0.38                   Clear
# ..         ...       ...       ...        ...                     ...
# 87        13.8  05:29:25  20:17:36       0.11        Partially cloudy
# 88        14.7  05:28:51  20:18:24       0.16        Partially cloudy
# 89        15.5  05:28:19  20:19:11       0.21  Rain, Partially cloudy
# 90        15.9  05:27:50  20:19:57       0.27                    Rain
# 91        16.0  05:27:22  20:20:41       0.33                   Clear
#
# [92 rows x 20 columns]

# %% [markdown]
# Change datetime to datetime format for the merge

# %%
weather_df['datetime'] = pd.to_datetime(weather_df['datetime'], format='%Y-%m-%d')

# %%
weather_df['sunrise'] = pd.to_datetime(weather_df['sunrise'], format='%H:%M:%S')
weather_df['sunset'] = pd.to_datetime(weather_df['sunset'], format='%H:%M:%S')

# %%
weather_df.dtypes
# Out:
# datetime        datetime64[ns]
# tempmax                float64
# tempmin                float64
# temp                   float64
# feelslikemax           float64
# feelslikemin           float64
# feelslike              float64
# dew                    float64
# humidity               float64
# precip                 float64
# snow                   float64
# snowdepth              float64
# windspeed              float64
# pressure               float64
# cloudcover             float64
# visibility             float64
# sunrise         datetime64[ns]
# sunset          datetime64[ns]
# moonphase              float64
# conditions              object
# dtype: object

# %%
weather_df
# Out:
#      datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  \
# 0  2020-03-01      8.7     -2.9   2.4           8.0          -7.4       -0.4
# 1  2020-03-02     14.3      3.9   9.1          14.3           1.8        8.4
# 2  2020-03-03     14.8      8.9  11.1          14.8           7.8       10.8
# 3  2020-03-04     13.8      7.2  10.2          13.8           3.2        8.9
# 4  2020-03-05     12.1      4.3   7.6          12.1           2.3        6.5
# ..        ...      ...      ...   ...           ...           ...        ...
# 87 2020-05-27     24.3     15.0  18.6          23.9          14.4       18.1
# 88 2020-05-28     23.9     16.8  20.1          24.3          15.0       18.6
# 89 2020-05-29     27.2     18.9  22.9          23.9          16.8       20.1
# 90 2020-05-30     28.3     19.4  23.5          28.5          18.9       23.1
# 91 2020-05-31     22.7     14.3  18.4          22.7          14.3       18.6
#
#      dew  humidity  precip  snow  snowdepth  windspeed  pressure  cloudcover  \
# 0   -8.4     46.32    0.00   0.0        0.0       22.0    1020.4         4.6
# 1    0.0     53.31    0.24   0.0        0.0       23.4    1014.9        14.5
# 2    7.1     77.41    7.93   0.0        0.0       14.7    1004.4        23.4
# 3   -0.2     50.65    0.97   0.0        0.0       39.6    1007.2         7.1
# 4   -2.1     51.97    0.00   0.0        0.0       14.1    1018.8         1.9
# ..   ...       ...     ...   ...        ...        ...       ...         ...
# 87  15.4     82.35    0.00   0.0        0.0       16.7    1023.7        31.4
# 88  17.8     86.89    0.00   0.0        0.0       20.6    1021.3        44.2
# 89  19.2     80.54    0.25   0.0        0.0       18.4    1015.3        38.1
# 90  13.8     58.76    0.02   0.0        0.0       18.4    1012.0        18.2
# 91   4.1     39.84    0.00   0.0        0.0       16.5    1018.0         7.7
#
#     visibility             sunrise              sunset  moonphase  \
# 0         16.0 1900-01-01 06:29:07 1900-01-01 17:47:57       0.18
# 1         16.0 1900-01-01 06:27:35 1900-01-01 17:49:05       0.23
# 2         14.3 1900-01-01 06:26:01 1900-01-01 17:50:13       0.28
# 3         16.0 1900-01-01 06:24:28 1900-01-01 17:51:20       0.34
# 4         16.0 1900-01-01 06:22:53 1900-01-01 17:52:27       0.38
# ..         ...                 ...                 ...        ...
# 87        13.8 1900-01-01 05:29:25 1900-01-01 20:17:36       0.11
# 88        14.7 1900-01-01 05:28:51 1900-01-01 20:18:24       0.16
# 89        15.5 1900-01-01 05:28:19 1900-01-01 20:19:11       0.21
# 90        15.9 1900-01-01 05:27:50 1900-01-01 20:19:57       0.27
# 91        16.0 1900-01-01 05:27:22 1900-01-01 20:20:41       0.33
#
#                 conditions
# 0                    Clear
# 1                     Rain
# 2                     Rain
# 3                     Rain
# 4                    Clear
# ..                     ...
# 87        Partially cloudy
# 88        Partially cloudy
# 89  Rain, Partially cloudy
# 90                    Rain
# 91                   Clear
#
# [92 rows x 20 columns]

# %% [markdown]
# Export the data to csv

# %%
weather_df.to_csv("C:/Users/MViki/Documents/CEU/Winter_semester/Coding_3/Term_project/Python_Final_Project/Data/Weather_data.csv")
